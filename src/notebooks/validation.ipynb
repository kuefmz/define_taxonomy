# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/matching_summaries/filtered_output_sim_not_1_05_-1.csv')

# %%
df
# Out:
#                         Category1   Source1                     Category2  \
# 0             appetite regulation  OpenAIRE                      appetite
# 1          context (language use)  OpenAIRE         context (archaeology)
# 2   pascal (programming language)  OpenAIRE                 pascal (unit)
# 3              lasso (statistics)  OpenAIRE  lasso (programming language)
# 4                  control theory  OpenAIRE    control theory (sociology)
# ..                            ...       ...                           ...
# 67                   dengue virus  OpenAIRE                  dengue fever
# 68                        octopus  OpenAIRE            octopus (software)
# 69         dissolved gas analysis  OpenAIRE               transformer oil
# 70    regularized meshless method  OpenAIRE      singular boundary method
# 71    aphasia primary progressive  OpenAIRE   primary progressive aphasia
#
#      Source2  Similarity  PapersInC1  PapersInC2  PapersInBoth  Agreement
# ...

# %%
columns = ['Category1', 'Category2', 'Source1', 'Source2', 'Agreement']
df_mapping = df[columns]

# %%
df_mapping.to_csv('mapping.csv', index=False)
