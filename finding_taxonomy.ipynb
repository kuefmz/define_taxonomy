# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Papers with code taxonomy

# %%
with open('papers_with_code_taxonomy.json', 'r') as f:
    papers_with_code = json.load(f)
#papers_with_code

# %%
papers_with_code[0]
# Out:
# {'url': 'https://paperswithcode.com/method/deep-ensembles',
#  'name': 'Deep Ensembles',
#  'full_name': 'Deep Ensembles',
#  'description': '',
#  'paper': {'title': 'Simple and Scalable Predictive Uncertainty Estimation using Deep Ensembles',
#   'url': 'https://paperswithcode.com/paper/simple-and-scalable-predictive-uncertainty'},
#  'introduced_year': 2000,
#  'source_url': 'http://arxiv.org/abs/1612.01474v3',
#  'source_title': 'Simple and Scalable Predictive Uncertainty Estimation using Deep Ensembles',
#  'code_snippet_url': None,
#  'num_papers': 103,
#  'collections': [{'collection': 'Stochastic Optimization',
#    'area_id': 'general',
#    'area': 'General'}]}

# %%
terms = set([])

# %%
term_count = {}
def add_to_count(term_count, term, taxonomy):
    if term in term_count.keys():
        term_count[term]['#papers'] += 1
        #print(term_count[term])
        if taxonomy not in term_count[term]['taxonomies']:
            term_count[term]['taxonomies'].append(taxonomy)
        
    else:
        term_count[term] = {'taxonomies': [taxonomy], '#papers': 1}
        #term_count[term]['taxonomies'].add()

# %%
for paper in papers_with_code:
    if 'collections' in paper.keys():
        for collection in paper['collections']:
            if 'area' in collection.keys() and 'collection' in collection.keys():
                mainclass = collection['area'].lower()
                subclass = collection['collection'].lower()
                terms.add(mainclass)
                terms.add(subclass)
                add_to_count(term_count, mainclass, 'papers_with_code')
                add_to_count(term_count, subclass, 'papers_with_code')

# %% [markdown]
# ## Wikidata taxonomy

# %% [markdown]
# ### AI

# %%
with open('query_ai2.json', 'r') as f:
    wikidata_ml = json.load(f)
for ml in wikidata_ml:
    mainclass = ml['aiclassLabel'].lower()
    add_to_count(term_count, mainclass, 'wikidata_ai')
    terms.add(mainclass)

# %% [markdown]
# ### ML

# %%
with open('query_ml1.json', 'r') as f:
    wikidata_ml = json.load(f)
for ml in wikidata_ml:
    mainclass = ml['aiclassLabel'].lower()
    add_to_count(term_count, mainclass, 'wikidata_ml')
    terms.add(mainclass)

# %% [markdown]
# ## CSO

# %%
df_cso = pd.read_csv('CSO.3.3_taxonomy.csv', header=None)
important_stuff = []
for ind, x in enumerate(df_cso.values):
    print(x)
    break
    if 'artificial_intelligence' in x[0]:
        subclass = x[2].split('/')[-1][:-1].replace('_', ' ').lower()
        add_to_count(term_count, subclass, 'cso')
        important_stuff.append(subclass)
# Out:
# ['<https://cso.kmi.open.ac.uk/topics/computer_science>'
#  '<http://cso.kmi.open.ac.uk/schema/cso#superTopicOf>'
#  '<https://cso.kmi.open.ac.uk/topics/artificial_intelligence>']

# %%
important_stuff
# Out:
# ['decision theory',
#  'intelligent control',
#  'natural language processing systems',
#  'formal logic',
#  'cognitive systems',
#  'soft computing',
#  'inference engines',
#  'medical computing',
#  'system theory',
#  'decision support systems',
#  'decision support system %28dss%29',
#  'bayesian networks',
#  'bayesian network',
#  'machine learning',
#  'machine-learning',
#  'cellular automata',
#  'cellular automata %28ca%29',
#  'knowledge based systems',
#  'knowledge-based systems',
#  'expert systems',
#  'expert system',
#  'multi agent system %28mas%29',
#  'multi-agent system',
#  'multi-agent systems',
#  'multi agent systems',
#  'multiagent systems',
#  'intelligent robots',
#  'ambient intelligence',
#  'heuristic programming',
#  'intelligent tutoring',
#  'intelligent tutoring system',
#  'intelligent tutoring systems',
#  'intelligence analysis',
#  'ai planning',
#  'planning algorithms',
#  'constraint satisfaction problems %28csp%29',
#  'software engineering',
#  'data mining',
#  'image interpretation%2c computer-assisted',
#  'computer assisted diagnosis',
#  'electronic commerce',
#  'information storage and retrieval',
#  'information management',
#  'automata theory',
#  'knowledge engineering',
#  'text processing',
#  'formal languages',
#  'conformal mapping',
#  'computability and decidability',
#  'non-determinism',
#  'state space',
#  'genetic programming',
#  'genetic programming %28gp%29',
#  'real time systems',
#  'real-time systems',
#  'evolutionary algorithms',
#  'evolutionary algorithm',
#  'model checking',
#  'model-checking',
#  'sensor networks',
#  'sensor network',
#  'recommender systems',
#  'recommender system',
#  'decision trees',
#  'decision tree',
#  'classifiers',
#  'classifier',
#  'adaptive systems',
#  'adaptive system',
#  'social networks',
#  'social network',
#  'multi objective optimizations %28moo%29',
#  'multiobjective optimization',
#  'multi-objective optimization',
#  'ontology',
#  'ontologies',
#  'wireless sensor network %28wsns%29',
#  'wireless sensor networks %28wsns%29',
#  'wireless sensor network %28wsn%29',
#  'wireless sensor networks',
#  'wireless sensor network',
#  'man machine systems',
#  'affective computing',
#  'ontology mapping',
#  'agent technology',
#  'tabu search',
#  'image classification',
#  'conjunctive queries',
#  'constraint programming',
#  'formal concept analysis',
#  'nsga-ii',
#  'evolutionary approach',
#  'self-adaptive',
#  'evolutionary process',
#  'data points',
#  'real data sets',
#  'word sense disambiguation',
#  'computational grammars',
#  'natural language generation',
#  'prolog %28programming language%29',
#  'constraint logic programming',
#  'event calculus',
#  'horn clause',
#  'learning agents',
#  'mergers and acquisitions',
#  'graph-based',
#  'probabilistic graphical models',
#  'activity recognition',
#  'mechanism design',
#  'automated theorem proving',
#  'information loss',
#  'text document',
#  'gibbs sampling',
#  'binary particle swarm optimization',
#  'attribute reduction algorithm',
#  'image annotation',
#  'computational resources',
#  'process mining',
#  'naive bayes',
#  'classification rules',
#  'formal approach',
#  'formal framework',
#  'tutoring system',
#  'computer assisted',
#  'heuristic search algorithms',
#  'exact inference',
#  'inference',
#  'scada systems',
#  'in-process',
#  'process-oriented',
#  'group members',
#  'user interests',
#  'user profiling',
#  'taxation',
#  'computer aided',
#  'reinforcement learning method',
#  'action spaces',
#  'model free',
#  'value function approximation',
#  'mutual informations',
#  'mutual information',
#  'first order logic',
#  'first-order logic',
#  'combinatorial auctions',
#  'combinatorial auction',
#  'modal logic',
#  'modal logics',
#  'high dimensional data',
#  'high-dimensional data',
#  'ensemble classifiers',
#  'ensemble classifier',
#  'descriptors',
#  'descriptor',
#  'visual feature',
#  'visual features',
#  'formal model',
#  'formal models',
#  'classifier ensembles',
#  'classifier ensemble',
#  'partially observable markov decision process',
#  'partially observable markov decision processes',
#  'memetic algorithms',
#  'memetic algorithm',
#  'matrix factorizations',
#  'matrix factorization',
#  'natural languages',
#  'natural language',
#  'coalition formations',
#  'coalition formation',
#  'data stream',
#  'data streams',
#  'personalization',
#  'personalizations',
#  'mobile agents',
#  'mobile agent',
#  'evolutionary computation',
#  'evolutionary computations',
#  'computing with words',
#  'computing with word %28cww%29',
#  'estimation of distribution algorithms',
#  'estimation of distribution algorithm',
#  'distributed environments',
#  'distributed environment',
#  'value functions',
#  'value function',
#  'personalized service',
#  'personalized services',
#  'evaluation models',
#  'evaluation model',
#  'binary classifiers',
#  'binary classification',
#  'agent based',
#  'agent-based',
#  'probabilistic models',
#  'probabilistic model',
#  'unified medical language system',
#  'unified medical language systems',
#  'user profile',
#  'user profiles',
#  'cross validation',
#  'cross-validation',
#  'satisfiability problems',
#  'satisfiability problem',
#  'self organizing',
#  'self-organizing',
#  'hierarchical structures',
#  'hierarchical structure',
#  'distributed architecture',
#  'distributed architectures',
#  'agent-based systems',
#  'agent-based system',
#  'domain knowledge',
#  'domain experts',
#  'human robot interaction',
#  'human-robot interaction',
#  'human robot interactions',
#  'markov decision process %28mdp%29',
#  'markov decision processes',
#  'markov decision process',
#  'computer-aided diagnosis %28cad%29',
#  'computer aided diagnosis',
#  'computer-aided diagnosis',
#  'student modeling',
#  'student models',
#  'student model',
#  'knowledge base',
#  'knowledge bases',
#  'cognitive modeling',
#  'cognitive model',
#  'cognitive models',
#  'supervised machine learning',
#  'unsupervised learning',
#  'background knowledge',
#  'automatic classification',
#  'class labels',
#  'epistemic logic',
#  'decision making%2c computer-assisted',
#  'swarm robotics',
#  'stigmergy',
#  'word similarity',
#  'fuzzy-neural',
#  'systems integration',
#  'textual data',
#  'biomedical literature',
#  'text data',
#  'continuous data',
#  'extracting information',
#  'free texts',
#  'player experience',
#  'game designers',
#  'affective state',
#  'natural language text',
#  'natural language understanding',
#  'knowledge engineers',
#  'single-agent',
#  'agent model',
#  'initial solution',
#  'numerical analysis%2c computer-assisted',
#  'cbr',
#  'cbr systems',
#  'case-based reasoning approaches',
#  'similar case',
#  'rule base',
#  'automatic evaluation',
#  'situation awareness',
#  'user preferences',
#  'latent variable models',
#  'boolean satisfiability',
#  'solution concepts',
#  'exploration and exploitation',
#  'candidate solution',
#  'memetic',
#  'k-nn classifier',
#  'k-nearest neighbor classifier',
#  'low-dimensional spaces',
#  'demonstrations',
#  're-planning',
#  'markov logic networks',
#  'sat-solving',
#  'dempster-shafer theory of evidence',
#  'sat problems',
#  'pedagogical agents',
#  'intelligent tutors',
#  'action language',
#  'nonlinear dimensionality reduction',
#  'low-dimensional manifolds',
#  'k-nn',
#  'high-dimensional feature space',
#  'multi-class problems',
#  'multi-class classifier',
#  'sequential decision making',
#  'spatial objects',
#  'user information',
#  'pair-wise comparison',
#  'preference information',
#  'computer integrated manufacturing',
#  'technical indicator',
#  'trading systems',
#  'bayesian networks %28bns%29',
#  'bayesian network classifiers',
#  'probabilistic modeling',
#  'solution accuracy',
#  'electric fault location',
#  'curse of dimensionality',
#  'programming framework',
#  'self-organize',
#  'proof system',
#  'traffic networks',
#  'expectation propagation',
#  'rule engine',
#  'dialogue',
#  'business decisions',
#  'proof search',
#  'continuous state',
#  'concept drifts',
#  'concept drift',
#  'embodied agent',
#  'embodied agents',
#  'latent variable',
#  'latent variables',
#  'decision support techniques',
#  'decision support systems%2c clinical',
#  'ordered weighted averaging',
#  'ordered weighted averaging operator',
#  'dynamic environments',
#  'dynamic environment',
#  'random projections',
#  'random projection',
#  'information content',
#  'information contents',
#  'binary classification problems',
#  'boosting',
#  'high-quality solutions',
#  'combining classifiers',
#  'casebased reasonings %28cbr%29',
#  'user activity',
#  'points of interest',
#  'supervised classifiers',
#  'appearance modeling',
#  'domain theory',
#  'crossover operations',
#  'learning from demonstration',
#  'decision models',
#  'decision model',
#  'document-processing',
#  'document processing',
#  'non-stationary environment',
#  'evaluation system',
#  'theoretical result',
#  'artificial intelligence@en ',
#  'cso#topic',
#  'distributed artificial intelligence@en ',
#  'cso#topic',
#  'game theory',
#  'genetic algorithm',
#  'machine learning techniques',
#  'machine learning methods',
#  'machine learning algorithms',
#  'genetic algorithm %28ga%29',
#  'genetic algorithms',
#  'intelligent systems',
#  'decision support system',
#  'machine learnings',
#  'multi agent system',
#  'multiagent system',
#  'swarm intelligence',
#  'natural language processing',
#  'nlp',
#  'commonsense',
#  'common-sense',
#  'commonsense reasoning',
#  'common-sense reasoning',
#  'common-sense computing',
#  'commonsense computing',
#  'common sense',
#  'ambient intelligent',
#  'bayesian approaches',
#  'bayesian approach',
#  'bayesian',
#  'bayesian model',
#  'bayesian models',
#  'bayesian method',
#  'bayesian frameworks',
#  'bayesian framework',
#  'bayesian methods',
#  'artificial intelligence',
#  'distributed artificial intelligence',
#  'q11660',
#  'q3153007',
#  'm.0mkz',
#  'm.01jgvl',
#  'distributed artificial intelligence',
#  'mx4rvvi4wjwpebgdrcn5y29yca',
#  '2777200204',
#  'artificial intelligence',
#  'distributed artificial intelligence']

# %%
for k in term_count.keys():
    print(f"term: {k} - #papers: {term_count[k]['#papers']} - taxonomies: {term_count[k]['taxonomies']}")
# Out:
# term: general - #papers: 990 - taxonomies: ['papers_with_code']
# term: stochastic optimization - #papers: 57 - taxonomies: ['papers_with_code']
# term: computer vision - #papers: 974 - taxonomies: ['papers_with_code']
# term: image generation models - #papers: 8 - taxonomies: ['papers_with_code']
# term: one-stage object detection models - #papers: 22 - taxonomies: ['papers_with_code']
# term: object detection models - #papers: 61 - taxonomies: ['papers_with_code']
# term: graphs - #papers: 108 - taxonomies: ['papers_with_code']
# term: graph representation learning - #papers: 10 - taxonomies: ['papers_with_code']
# term: face recognition models - #papers: 6 - taxonomies: ['papers_with_code']
# term: image retrieval models - #papers: 3 - taxonomies: ['papers_with_code']
# term: skip connection blocks - #papers: 46 - taxonomies: ['papers_with_code']
# term: audio - #papers: 57 - taxonomies: ['papers_with_code']
# term: audio model blocks - #papers: 13 - taxonomies: ['papers_with_code']
# term: generative adversarial networks - #papers: 43 - taxonomies: ['papers_with_code']
# term: graph models - #papers: 61 - taxonomies: ['papers_with_code']
# term: feature extractors - #papers: 26 - taxonomies: ['papers_with_code']
# term: attention mechanisms - #papers: 72 - taxonomies: ['papers_with_code']
# term: pooling operations - #papers: 17 - taxonomies: ['papers_with_code']
# term: sequential - #papers: 73 - taxonomies: ['papers_with_code']
# term: time series analysis - #papers: 7 - taxonomies: ['papers_with_code']
# term: adaptive activation functions - #papers: 12 - taxonomies: ['papers_with_code']
# term: activation functions - #papers: 62 - taxonomies: ['papers_with_code']
# term: natural language processing - #papers: 285 - taxonomies: ['papers_with_code', 'wikidata_ai', 'cso']
# term: autoregressive transformers - #papers: 17 - taxonomies: ['papers_with_code']
# term: transformers - #papers: 81 - taxonomies: ['papers_with_code']
# term: sequence to sequence models - #papers: 17 - taxonomies: ['papers_with_code']
# term: rule learners - #papers: 1 - taxonomies: ['papers_with_code']
# term: generative models - #papers: 64 - taxonomies: ['papers_with_code']
# term: reinforcement learning - #papers: 101 - taxonomies: ['papers_with_code', 'wikidata_ai', 'wikidata_ml']
# term: heuristic search algorithms - #papers: 7 - taxonomies: ['papers_with_code', 'cso']
# term: roi feature extractors - #papers: 12 - taxonomies: ['papers_with_code']
# term: language models - #papers: 47 - taxonomies: ['papers_with_code']
# term: 3d representations - #papers: 9 - taxonomies: ['papers_with_code']
# term: regularization - #papers: 53 - taxonomies: ['papers_with_code']
# term: contextualized word embeddings - #papers: 7 - taxonomies: ['papers_with_code']
# term: normalization - #papers: 37 - taxonomies: ['papers_with_code']
# term: image model blocks - #papers: 90 - taxonomies: ['papers_with_code']
# term: convolutional neural networks - #papers: 116 - taxonomies: ['papers_with_code']
# term: graph embeddings - #papers: 36 - taxonomies: ['papers_with_code']
# term: image models - #papers: 33 - taxonomies: ['papers_with_code']
# term: vision transformers - #papers: 43 - taxonomies: ['papers_with_code']
# term: speech separation models - #papers: 5 - taxonomies: ['papers_with_code']
# term: non-parametric regression - #papers: 7 - taxonomies: ['papers_with_code']
# term: non-parametric classification - #papers: 4 - taxonomies: ['papers_with_code']
# term: discriminators - #papers: 6 - taxonomies: ['papers_with_code']
# term: image data augmentation - #papers: 33 - taxonomies: ['papers_with_code']
# term: self-supervised learning - #papers: 45 - taxonomies: ['papers_with_code', 'wikidata_ai', 'wikidata_ml']
# term: autoencoding transformers - #papers: 28 - taxonomies: ['papers_with_code']
# term: learning rate schedules - #papers: 12 - taxonomies: ['papers_with_code']
# term: data parallel methods - #papers: 16 - taxonomies: ['papers_with_code']
# term: speaker diarization - #papers: 1 - taxonomies: ['papers_with_code']
# term: optimization - #papers: 28 - taxonomies: ['papers_with_code']
# term: convolutions - #papers: 41 - taxonomies: ['papers_with_code']
# term: whitening - #papers: 2 - taxonomies: ['papers_with_code']
# term: deep tabular learning - #papers: 26 - taxonomies: ['papers_with_code']
# term: loss functions - #papers: 37 - taxonomies: ['papers_with_code']
# term: kernel methods - #papers: 2 - taxonomies: ['papers_with_code']
# term: unpaired image-to-image translation - #papers: 4 - taxonomies: ['papers_with_code']
# term: image representations - #papers: 11 - taxonomies: ['papers_with_code']
# term: sentence embeddings - #papers: 8 - taxonomies: ['papers_with_code']
# term: semi-supervised learning methods - #papers: 23 - taxonomies: ['papers_with_code']
# term: miscellaneous components - #papers: 9 - taxonomies: ['papers_with_code']
# term: 6d pose estimation models - #papers: 3 - taxonomies: ['papers_with_code']
# term: font generation models - #papers: 1 - taxonomies: ['papers_with_code']
# term: automl - #papers: 9 - taxonomies: ['papers_with_code']
# term: theorem proving models - #papers: 1 - taxonomies: ['papers_with_code']
# term: q-learning networks - #papers: 8 - taxonomies: ['papers_with_code']
# term: semantic segmentation models - #papers: 31 - taxonomies: ['papers_with_code']
# term: text-to-speech models - #papers: 11 - taxonomies: ['papers_with_code']
# term: information retrieval methods - #papers: 2 - taxonomies: ['papers_with_code']
# term: passage re-ranking models - #papers: 1 - taxonomies: ['papers_with_code']
# term: active learning - #papers: 6 - taxonomies: ['papers_with_code', 'wikidata_ai', 'wikidata_ml']
# term: text classification models - #papers: 5 - taxonomies: ['papers_with_code']
# term: interpretability - #papers: 14 - taxonomies: ['papers_with_code']
# term: video model blocks - #papers: 6 - taxonomies: ['papers_with_code']
# term: vision and language pre-trained models - #papers: 28 - taxonomies: ['papers_with_code']
# term: multi-modal methods - #papers: 8 - taxonomies: ['papers_with_code']
# term: webpage object detection pipeline - #papers: 1 - taxonomies: ['papers_with_code']
# term: attention modules - #papers: 41 - taxonomies: ['papers_with_code']
# term: recurrent neural networks - #papers: 32 - taxonomies: ['papers_with_code']
# term: generative audio models - #papers: 16 - taxonomies: ['papers_with_code']
# term: position embeddings - #papers: 5 - taxonomies: ['papers_with_code']
# term: adversarial training - #papers: 14 - taxonomies: ['papers_with_code']
# term: feedforward networks - #papers: 16 - taxonomies: ['papers_with_code']
# term: knowledge distillation - #papers: 12 - taxonomies: ['papers_with_code', 'wikidata_ai', 'wikidata_ml']
# term: style transfer models - #papers: 1 - taxonomies: ['papers_with_code']
# term: instance segmentation modules - #papers: 5 - taxonomies: ['papers_with_code']
# term: style transfer modules - #papers: 2 - taxonomies: ['papers_with_code']
# term: policy gradient methods - #papers: 23 - taxonomies: ['papers_with_code']
# term: generative video models - #papers: 9 - taxonomies: ['papers_with_code']
# term: 3d reconstruction - #papers: 6 - taxonomies: ['papers_with_code']
# term: degridding - #papers: 1 - taxonomies: ['papers_with_code']
# term: word embeddings - #papers: 14 - taxonomies: ['papers_with_code']
# term: thermal image processing models - #papers: 1 - taxonomies: ['papers_with_code']
# term: structured prediction - #papers: 5 - taxonomies: ['papers_with_code', 'wikidata_ai', 'wikidata_ml']
# term: generalized linear models - #papers: 3 - taxonomies: ['papers_with_code']
# term: pose estimation models - #papers: 5 - taxonomies: ['papers_with_code']
# term: region proposal - #papers: 5 - taxonomies: ['papers_with_code']
# term: rl transformers - #papers: 2 - taxonomies: ['papers_with_code']
# term: ensembling - #papers: 1 - taxonomies: ['papers_with_code']
# term: scene text models - #papers: 3 - taxonomies: ['papers_with_code']
# term: bayesian reinforcement learning - #papers: 1 - taxonomies: ['papers_with_code']
# term: video-text retrieval models - #papers: 2 - taxonomies: ['papers_with_code']
# term: open-domain chatbots - #papers: 1 - taxonomies: ['papers_with_code']
# term: conversational models - #papers: 2 - taxonomies: ['papers_with_code']
# term: instance segmentation models - #papers: 15 - taxonomies: ['papers_with_code']
# term: fuzzy logic - #papers: 1 - taxonomies: ['papers_with_code']
# term: table parsing models - #papers: 1 - taxonomies: ['papers_with_code']
# term: domain adaptation - #papers: 14 - taxonomies: ['papers_with_code']
# term: distributed methods - #papers: 39 - taxonomies: ['papers_with_code']
# term: 3d face mesh models - #papers: 2 - taxonomies: ['papers_with_code']
# term: point cloud models - #papers: 8 - taxonomies: ['papers_with_code']
# term: reinforcement learning frameworks - #papers: 4 - taxonomies: ['papers_with_code']
# term: medical image models - #papers: 3 - taxonomies: ['papers_with_code']
# term: proposal filtering - #papers: 7 - taxonomies: ['papers_with_code']
# term: feature pyramid blocks - #papers: 11 - taxonomies: ['papers_with_code']
# term: video frame interpolation - #papers: 2 - taxonomies: ['papers_with_code']
# term: robotic manipulation models - #papers: 2 - taxonomies: ['papers_with_code']
# term: 3d object detection models - #papers: 9 - taxonomies: ['papers_with_code']
# term: pruning - #papers: 3 - taxonomies: ['papers_with_code']
# term: value function estimation - #papers: 6 - taxonomies: ['papers_with_code']
# term: document summary evaluation - #papers: 1 - taxonomies: ['papers_with_code']
# term: multi-object tracking models - #papers: 7 - taxonomies: ['papers_with_code']
# term: text augmentation - #papers: 2 - taxonomies: ['papers_with_code']
# term: representation learning - #papers: 4 - taxonomies: ['papers_with_code']
# term: few-shot image-to-image translation - #papers: 1 - taxonomies: ['papers_with_code']
# term: attention patterns - #papers: 8 - taxonomies: ['papers_with_code']
# term: offline reinforcement learning methods - #papers: 3 - taxonomies: ['papers_with_code']
# term: action recognition models - #papers: 4 - taxonomies: ['papers_with_code']
# term: table question answering models - #papers: 2 - taxonomies: ['papers_with_code']
# term: on-policy td control - #papers: 5 - taxonomies: ['papers_with_code']
# term: imitation learning methods - #papers: 5 - taxonomies: ['papers_with_code']
# term: neural architecture search - #papers: 20 - taxonomies: ['papers_with_code']
# term: dimensionality reduction - #papers: 7 - taxonomies: ['papers_with_code']
# term: explainable cnns - #papers: 2 - taxonomies: ['papers_with_code']
# term: affinity functions - #papers: 4 - taxonomies: ['papers_with_code']
# term: prompt engineering - #papers: 3 - taxonomies: ['papers_with_code', 'wikidata_ai']
# term: hyperparameter search - #papers: 4 - taxonomies: ['papers_with_code']
# term: meta-learning algorithms - #papers: 5 - taxonomies: ['papers_with_code']
# term: off-policy td control - #papers: 5 - taxonomies: ['papers_with_code']
# term: trajectory prediction models - #papers: 1 - taxonomies: ['papers_with_code']
# term: likelihood-based generative models - #papers: 10 - taxonomies: ['papers_with_code']
# term: document embeddings - #papers: 3 - taxonomies: ['papers_with_code']
# term: sparsity - #papers: 1 - taxonomies: ['papers_with_code']
# term: graph data augmentation - #papers: 1 - taxonomies: ['papers_with_code']
# term: large batch optimization - #papers: 11 - taxonomies: ['papers_with_code']
# term: video recognition models - #papers: 3 - taxonomies: ['papers_with_code']
# term: downsampling - #papers: 2 - taxonomies: ['papers_with_code']
# term: behaviour policies - #papers: 2 - taxonomies: ['papers_with_code']
# term: clustering - #papers: 14 - taxonomies: ['papers_with_code']
# term: topic embeddings - #papers: 2 - taxonomies: ['papers_with_code']
# term: 2d parallel distributed methods - #papers: 3 - taxonomies: ['papers_with_code']
# term: hybrid parallel methods - #papers: 6 - taxonomies: ['papers_with_code']
# term: counting methods - #papers: 1 - taxonomies: ['papers_with_code']
# term: cashier-free shopping - #papers: 1 - taxonomies: ['papers_with_code']
# term: spreadsheet formula prediction models - #papers: 1 - taxonomies: ['papers_with_code']
# term: subword segmentation - #papers: 4 - taxonomies: ['papers_with_code']
# term: temporal convolutions - #papers: 8 - taxonomies: ['papers_with_code']
# term: gated linear networks - #papers: 3 - taxonomies: ['papers_with_code']
# term: face restoration models - #papers: 5 - taxonomies: ['papers_with_code']
# term: image semantic segmentation metric - #papers: 1 - taxonomies: ['papers_with_code']
# term: textual inference models - #papers: 1 - taxonomies: ['papers_with_code']
# term: interactive semantic segmentation models - #papers: 1 - taxonomies: ['papers_with_code']
# term: question answering models - #papers: 3 - taxonomies: ['papers_with_code']
# term: statistical inference - #papers: 1 - taxonomies: ['papers_with_code']
# term: distributed communication - #papers: 1 - taxonomies: ['papers_with_code']
# term: hybrid fuzzing - #papers: 1 - taxonomies: ['papers_with_code']
# term: hybrid optimization - #papers: 2 - taxonomies: ['papers_with_code']
# term: language model pre-training - #papers: 4 - taxonomies: ['papers_with_code']
# term: anchor generation modules - #papers: 2 - taxonomies: ['papers_with_code']
# term: rule-based systems - #papers: 3 - taxonomies: ['papers_with_code']
# term: adversarial image data augmentation - #papers: 3 - taxonomies: ['papers_with_code']
# term: attention - #papers: 7 - taxonomies: ['papers_with_code']
# term: initialization - #papers: 7 - taxonomies: ['papers_with_code']
# term: multi-scale training - #papers: 2 - taxonomies: ['papers_with_code']
# term: prioritized sampling - #papers: 4 - taxonomies: ['papers_with_code']
# term: dialog adaptation - #papers: 1 - taxonomies: ['papers_with_code']
# term: skip connections - #papers: 4 - taxonomies: ['papers_with_code']
# term: image denoising models - #papers: 4 - taxonomies: ['papers_with_code']
# term: mesh-based simulation models - #papers: 1 - taxonomies: ['papers_with_code']
# term: adaptive computation - #papers: 2 - taxonomies: ['papers_with_code']
# term: object detection modules - #papers: 1 - taxonomies: ['papers_with_code']
# term: video instance segmentation models - #papers: 1 - taxonomies: ['papers_with_code']
# term: asynchronous data parallel - #papers: 3 - taxonomies: ['papers_with_code']
# term: policy evaluation - #papers: 1 - taxonomies: ['papers_with_code']
# term: vqa models - #papers: 2 - taxonomies: ['papers_with_code']
# term: image super-resolution models - #papers: 2 - taxonomies: ['papers_with_code']
# term: distillation - #papers: 1 - taxonomies: ['papers_with_code']
# term: distributed reinforcement learning - #papers: 6 - taxonomies: ['papers_with_code']
# term: code generation transformers - #papers: 4 - taxonomies: ['papers_with_code']
# term: adversarial attacks - #papers: 3 - taxonomies: ['papers_with_code']
# term: generative discrimination - #papers: 1 - taxonomies: ['papers_with_code']
# term: asynchronous pipeline parallel - #papers: 4 - taxonomies: ['papers_with_code']
# term: model parallel methods - #papers: 9 - taxonomies: ['papers_with_code']
# term: reversible image conversion models - #papers: 2 - taxonomies: ['papers_with_code']
# term: pose estimation blocks - #papers: 2 - taxonomies: ['papers_with_code']
# term: relation extraction models - #papers: 3 - taxonomies: ['papers_with_code']
# term: eligibility traces - #papers: 4 - taxonomies: ['papers_with_code']
# term: synchronous pipeline parallel - #papers: 2 - taxonomies: ['papers_with_code']
# term: sequence decoding methods - #papers: 1 - taxonomies: ['papers_with_code']
# term: stereo depth estimation models - #papers: 3 - taxonomies: ['papers_with_code']
# term: board game models - #papers: 3 - taxonomies: ['papers_with_code']
# term: super-resolution models - #papers: 1 - taxonomies: ['papers_with_code']
# term: working memory models - #papers: 5 - taxonomies: ['papers_with_code']
# term: intra-layer parallel - #papers: 3 - taxonomies: ['papers_with_code']
# term: sharded data parallel methods - #papers: 3 - taxonomies: ['papers_with_code']
# term: portrait matting models - #papers: 2 - taxonomies: ['papers_with_code']
# term: video game models - #papers: 2 - taxonomies: ['papers_with_code']
# term: binary neural networks - #papers: 1 - taxonomies: ['papers_with_code']
# term: rendezvous - #papers: 1 - taxonomies: ['papers_with_code']
# term: video panoptic segmentation models - #papers: 2 - taxonomies: ['papers_with_code']
# term: negative sampling - #papers: 1 - taxonomies: ['papers_with_code']
# term: tabular data generation - #papers: 1 - taxonomies: ['papers_with_code']
# term: output functions - #papers: 9 - taxonomies: ['papers_with_code']
# term: reading comprehension models - #papers: 1 - taxonomies: ['papers_with_code']
# term: meshing - #papers: 2 - taxonomies: ['papers_with_code']
# term: replay memory - #papers: 2 - taxonomies: ['papers_with_code']
# term: backbone architectures - #papers: 4 - taxonomies: ['papers_with_code']
# term: model compression - #papers: 2 - taxonomies: ['papers_with_code']
# term: tokenizers - #papers: 2 - taxonomies: ['papers_with_code']
# term: image quality models - #papers: 1 - taxonomies: ['papers_with_code']
# term: card game models - #papers: 1 - taxonomies: ['papers_with_code']
# term: bidirectional recurrent neural networks - #papers: 4 - taxonomies: ['papers_with_code']
# term: point cloud augmentation - #papers: 2 - taxonomies: ['papers_with_code']
# term: ocr models - #papers: 2 - taxonomies: ['papers_with_code']
# term: sample re-weighting - #papers: 1 - taxonomies: ['papers_with_code']
# term: semantic segmentation modules - #papers: 12 - taxonomies: ['papers_with_code']
# term: speech recognition - #papers: 4 - taxonomies: ['papers_with_code', 'wikidata_ai']
# term: layout annotation models - #papers: 1 - taxonomies: ['papers_with_code']
# term: distribution approximation - #papers: 2 - taxonomies: ['papers_with_code']
# term: image restoration models - #papers: 4 - taxonomies: ['papers_with_code']
# term: variational optimization - #papers: 3 - taxonomies: ['papers_with_code']
# term: static word embeddings - #papers: 7 - taxonomies: ['papers_with_code']
# term: generative training - #papers: 3 - taxonomies: ['papers_with_code']
# term: efficient planning - #papers: 1 - taxonomies: ['papers_with_code']
# term: monocular depth estimation models - #papers: 2 - taxonomies: ['papers_with_code']
# term: recommendation systems - #papers: 3 - taxonomies: ['papers_with_code']
# term: video super-resolution models - #papers: 1 - taxonomies: ['papers_with_code']
# term: reading order detection models - #papers: 1 - taxonomies: ['papers_with_code']
# term: video data augmentation - #papers: 1 - taxonomies: ['papers_with_code']
# term: image segmentation models - #papers: 6 - taxonomies: ['papers_with_code']
# term: rgb-d saliency detection models - #papers: 1 - taxonomies: ['papers_with_code']
# term: information bottleneck - #papers: 2 - taxonomies: ['papers_with_code']
# term: robust training - #papers: 4 - taxonomies: ['papers_with_code']
# term: image scaling strategies - #papers: 1 - taxonomies: ['papers_with_code']
# term: fourier-related transforms - #papers: 2 - taxonomies: ['papers_with_code']
# term: oriented object detection models - #papers: 1 - taxonomies: ['papers_with_code']
# term: distributions - #papers: 1 - taxonomies: ['papers_with_code']
# term: lane detection models - #papers: 1 - taxonomies: ['papers_with_code']
# term: input embedding factorization - #papers: 1 - taxonomies: ['papers_with_code']
# term: entity recognition models - #papers: 1 - taxonomies: ['papers_with_code']
# term: quantum methods - #papers: 4 - taxonomies: ['papers_with_code']
# term: randomized value functions - #papers: 2 - taxonomies: ['papers_with_code']
# term: label correction - #papers: 1 - taxonomies: ['papers_with_code']
# term: localization models - #papers: 2 - taxonomies: ['papers_with_code']
# term: cache replacement models - #papers: 1 - taxonomies: ['papers_with_code']
# term: parameter norm penalties - #papers: 2 - taxonomies: ['papers_with_code']
# term: exaggeration detection models - #papers: 1 - taxonomies: ['papers_with_code']
# term: video object segmentation models - #papers: 3 - taxonomies: ['papers_with_code']
# term: state similarity metrics - #papers: 1 - taxonomies: ['papers_with_code']
# term: parameter server methods - #papers: 4 - taxonomies: ['papers_with_code']
# term: image colorization models - #papers: 1 - taxonomies: ['papers_with_code']
# term: lifelong learning - #papers: 2 - taxonomies: ['papers_with_code']
# term: person search models - #papers: 1 - taxonomies: ['papers_with_code']
# term: time series modules - #papers: 2 - taxonomies: ['papers_with_code']
# term: textual meaning - #papers: 1 - taxonomies: ['papers_with_code']
# term: text instance representations - #papers: 1 - taxonomies: ['papers_with_code']
# term: paraphrase generation models - #papers: 1 - taxonomies: ['papers_with_code']
# term: fine-tuning - #papers: 4 - taxonomies: ['papers_with_code']
# term: bijective transformation - #papers: 1 - taxonomies: ['papers_with_code']
# term: synthesized attention mechanisms - #papers: 4 - taxonomies: ['papers_with_code']
# term: replicated data parallel - #papers: 4 - taxonomies: ['papers_with_code']
# term: trajectory data augmentation - #papers: 1 - taxonomies: ['papers_with_code']
# term: feature matching - #papers: 2 - taxonomies: ['papers_with_code']
# term: phase reconstruction - #papers: 2 - taxonomies: ['papers_with_code']
# term: auto parallel methods - #papers: 3 - taxonomies: ['papers_with_code']
# term: inference attack - #papers: 1 - taxonomies: ['papers_with_code']
# term: robustness methods - #papers: 2 - taxonomies: ['papers_with_code']
# term: text data augmentation - #papers: 1 - taxonomies: ['papers_with_code']
# term: inference extrapolation - #papers: 1 - taxonomies: ['papers_with_code']
# term: markov chain monte carlo - #papers: 3 - taxonomies: ['papers_with_code']
# term: mixture-of-experts - #papers: 1 - taxonomies: ['papers_with_code']
# term: face-to-face translation - #papers: 1 - taxonomies: ['papers_with_code']
# term: conditional image-to-image translation models - #papers: 3 - taxonomies: ['papers_with_code']
# term: face privacy - #papers: 2 - taxonomies: ['papers_with_code']
# term: graphics models - #papers: 1 - taxonomies: ['papers_with_code']
# term: actor-critic algorithms - #papers: 1 - taxonomies: ['papers_with_code']
# term: bot detection - #papers: 1 - taxonomies: ['papers_with_code']
# term: generalized additive models - #papers: 2 - taxonomies: ['papers_with_code']
# term: human object interaction detectors - #papers: 1 - taxonomies: ['papers_with_code']
# term: inference engines - #papers: 2 - taxonomies: ['papers_with_code', 'cso']
# term: air quality forecasting - #papers: 1 - taxonomies: ['papers_with_code']
# term: out-of-distribution example detection - #papers: 1 - taxonomies: ['papers_with_code']
# term: copy mechanisms - #papers: 1 - taxonomies: ['papers_with_code']
# term: self-training methods - #papers: 1 - taxonomies: ['papers_with_code']
# term: latent variable sampling - #papers: 3 - taxonomies: ['papers_with_code']
# term: sequence editing models - #papers: 1 - taxonomies: ['papers_with_code']
# term: image feature extractors - #papers: 4 - taxonomies: ['papers_with_code']
# term: action recognition blocks - #papers: 2 - taxonomies: ['papers_with_code']
# term: audio artifact removal - #papers: 1 - taxonomies: ['papers_with_code']
# term: confidence calibration - #papers: 1 - taxonomies: ['papers_with_code']
# term: speech enhancement - #papers: 1 - taxonomies: ['papers_with_code']
# term: music source separation - #papers: 1 - taxonomies: ['papers_with_code']
# term: factorization machines - #papers: 1 - taxonomies: ['papers_with_code']
# term: feature upsampling - #papers: 1 - taxonomies: ['papers_with_code']
# term: environment design methods - #papers: 1 - taxonomies: ['papers_with_code']
# term: dependency parsers - #papers: 1 - taxonomies: ['papers_with_code']
# term: confidence estimators - #papers: 1 - taxonomies: ['papers_with_code']
# term: video sampling - #papers: 1 - taxonomies: ['papers_with_code']
# term: output heads - #papers: 1 - taxonomies: ['papers_with_code']
# term: image manipulation models - #papers: 1 - taxonomies: ['papers_with_code']
# term: slam methods - #papers: 2 - taxonomies: ['papers_with_code']
# term: dialogue state trackers - #papers: 1 - taxonomies: ['papers_with_code']
# term: incident aggregation models - #papers: 1 - taxonomies: ['papers_with_code']
# term: taxonomy expansion models - #papers: 1 - taxonomies: ['papers_with_code']
# term: point cloud representations - #papers: 2 - taxonomies: ['papers_with_code']
# term: detection assignment rules - #papers: 1 - taxonomies: ['papers_with_code']
# term: global context modules - #papers: 1 - taxonomies: ['papers_with_code']
# term: document understanding models - #papers: 1 - taxonomies: ['papers_with_code']
# term: generalization - #papers: 1 - taxonomies: ['papers_with_code']
# term: image inpainting modules - #papers: 1 - taxonomies: ['papers_with_code']
# term: augmented reality methods - #papers: 2 - taxonomies: ['papers_with_code']
# term: arbitrary object detectors - #papers: 1 - taxonomies: ['papers_with_code']
# term: momentum rules - #papers: 1 - taxonomies: ['papers_with_code']
# term: network shrinking - #papers: 2 - taxonomies: ['papers_with_code']
# term: control and decision systems - #papers: 1 - taxonomies: ['papers_with_code']
# term: path planning - #papers: 1 - taxonomies: ['papers_with_code']
# term: motion control - #papers: 1 - taxonomies: ['papers_with_code']
# term: density ratio learning - #papers: 1 - taxonomies: ['papers_with_code']
# term: approximate inference - #papers: 1 - taxonomies: ['papers_with_code']
# term: video inpainting models - #papers: 1 - taxonomies: ['papers_with_code']
# term: language model components - #papers: 1 - taxonomies: ['papers_with_code']
# term: image decomposition models - #papers: 1 - taxonomies: ['papers_with_code']
# term: manifold disentangling - #papers: 1 - taxonomies: ['papers_with_code']
# term: medical waveform analysis - #papers: 1 - taxonomies: ['papers_with_code']
# term: sequential blocks - #papers: 1 - taxonomies: ['papers_with_code']
# term: speech synthesis blocks - #papers: 1 - taxonomies: ['papers_with_code']
# term: learning to rank models - #papers: 1 - taxonomies: ['papers_with_code']
# term: dialog system evaluation - #papers: 1 - taxonomies: ['papers_with_code']
# term: mask branches - #papers: 1 - taxonomies: ['papers_with_code']
# term: deraining models - #papers: 1 - taxonomies: ['papers_with_code']
# term: music transcription - #papers: 1 - taxonomies: ['papers_with_code']
# term: entity retrieval models - #papers: 1 - taxonomies: ['papers_with_code']
# term: machine translation models - #papers: 1 - taxonomies: ['papers_with_code']
# term: generative sequence models - #papers: 1 - taxonomies: ['papers_with_code']
# term: anchor supervision - #papers: 1 - taxonomies: ['papers_with_code']
# term: twin networks - #papers: 1 - taxonomies: ['papers_with_code']
# term: position recovery models - #papers: 1 - taxonomies: ['papers_with_code']
# term: video interpolation models - #papers: 1 - taxonomies: ['papers_with_code']
# term: motion prediction models - #papers: 1 - taxonomies: ['papers_with_code']
# term: video quality models - #papers: 1 - taxonomies: ['papers_with_code']
# term: geometric matching - #papers: 1 - taxonomies: ['papers_with_code']
# term: ternarization - #papers: 1 - taxonomies: ['papers_with_code']
# term: math formula detection models - #papers: 1 - taxonomies: ['papers_with_code']
# term: exploration strategies - #papers: 1 - taxonomies: ['papers_with_code']
# term: parameter sharing - #papers: 1 - taxonomies: ['papers_with_code']
# term: span representations - #papers: 1 - taxonomies: ['papers_with_code']
# term: cad design models - #papers: 1 - taxonomies: ['papers_with_code']
# term: speech embeddings - #papers: 1 - taxonomies: ['papers_with_code']
# term: long-range interaction layers - #papers: 1 - taxonomies: ['papers_with_code']
# term: leadership inference - #papers: 1 - taxonomies: ['papers_with_code']
# term: machine learning - #papers: 2 - taxonomies: ['wikidata_ai', 'cso']
# term: expert system - #papers: 2 - taxonomies: ['wikidata_ai', 'cso']
# term: decision support system - #papers: 2 - taxonomies: ['wikidata_ai', 'cso']
# term: computational intelligence - #papers: 1 - taxonomies: ['wikidata_ai']
# term: affective computing - #papers: 2 - taxonomies: ['wikidata_ai', 'cso']
# term: evolutionary computation - #papers: 2 - taxonomies: ['wikidata_ai', 'cso']
# term: knowledge engineering - #papers: 2 - taxonomies: ['wikidata_ai', 'cso']
# term: heuristic algorithm - #papers: 1 - taxonomies: ['wikidata_ai']
# term: automated planning and scheduling - #papers: 1 - taxonomies: ['wikidata_ai']
# term: distributed artificial intelligence - #papers: 4 - taxonomies: ['wikidata_ai', 'cso']
# term: knowledge representation and reasoning - #papers: 1 - taxonomies: ['wikidata_ai']
# term: self-management - #papers: 1 - taxonomies: ['wikidata_ai']
# term: applications of artificial intelligence - #papers: 1 - taxonomies: ['wikidata_ai']
# term: symbolic artificial intelligence - #papers: 1 - taxonomies: ['wikidata_ai']
# term: neurorobotics - #papers: 1 - taxonomies: ['wikidata_ai']
# term: intelligent robotics - #papers: 1 - taxonomies: ['wikidata_ai']
# term: fictional robot - #papers: 1 - taxonomies: ['wikidata_ai']
# term: artificial intelligence in fiction - #papers: 1 - taxonomies: ['wikidata_ai']
# term: artificial empathy - #papers: 1 - taxonomies: ['wikidata_ai']
# term: artificial intelligence in healthcare - #papers: 1 - taxonomies: ['wikidata_ai']
# term: explainable ai - #papers: 1 - taxonomies: ['wikidata_ai']
# term: federated learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: multimodal sentiment analysis - #papers: 1 - taxonomies: ['wikidata_ai']
# term: artificial intelligence in wikimedia projects - #papers: 1 - taxonomies: ['wikidata_ai']
# term: quantum artificial intelligence - #papers: 1 - taxonomies: ['wikidata_ai']
# term: artificial chemist - #papers: 1 - taxonomies: ['wikidata_ai']
# term: associatron - #papers: 1 - taxonomies: ['wikidata_ai']
# term: automated music production - #papers: 1 - taxonomies: ['wikidata_ai']
# term: autonomous navigation - #papers: 1 - taxonomies: ['wikidata_ai']
# term: green ai - #papers: 1 - taxonomies: ['wikidata_ai']
# term: red ai - #papers: 1 - taxonomies: ['wikidata_ai']
# term: ethical artificial intelligence - #papers: 1 - taxonomies: ['wikidata_ai']
# term: responsible ai - #papers: 1 - taxonomies: ['wikidata_ai']
# term: vision and language - #papers: 1 - taxonomies: ['wikidata_ai']
# term: artificial intelligence in material science - #papers: 1 - taxonomies: ['wikidata_ai']
# term: neuro-symbolic ai - #papers: 1 - taxonomies: ['wikidata_ai']
# term: strong ai and weak ai - #papers: 1 - taxonomies: ['wikidata_ai']
# term: applied artificial intelligence - #papers: 1 - taxonomies: ['wikidata_ai']
# term: machine unlearning - #papers: 1 - taxonomies: ['wikidata_ai']
# term: autonomous technologies - #papers: 1 - taxonomies: ['wikidata_ai']
# term: explanation-based learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: pattern recognition - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: hierarchical temporal memory - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: chemometrics - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: unsupervised learning - #papers: 3 - taxonomies: ['wikidata_ai', 'wikidata_ml', 'cso']
# term: statistical classification - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: transfer learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: meta-learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: multi-task learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: nonlinear dimensionality reduction - #papers: 3 - taxonomies: ['wikidata_ai', 'wikidata_ml', 'cso']
# term: offline learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: one-shot learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: online machine learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: preference learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: robot learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: statistical relational learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: feature learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: quantum machine learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: adversarial machine learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: multiple kernel learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: multimodal learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: m-theory - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: rule-based machine learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: incremental learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: machine learning in bioinformatics - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: sequence-to-sequence learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: automated machine learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: image-to-image translation - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: interactive machine learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: end-to-end learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: machine learning in physics - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: zero-shot learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: gossip learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: declarative machine learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: byy harmony learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: few-shot learning - #papers: 3 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: pathways - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: semi-supervised and unsupervised learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: personalized machine learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: continual learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: imbalanced learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: natural language understanding - #papers: 2 - taxonomies: ['wikidata_ai', 'cso']
# term: part-of-speech tagging - #papers: 1 - taxonomies: ['wikidata_ai']
# term: natural language generation - #papers: 2 - taxonomies: ['wikidata_ai', 'cso']
# term: morphological analysis - #papers: 1 - taxonomies: ['wikidata_ai']
# term: text segmentation - #papers: 1 - taxonomies: ['wikidata_ai']
# term: tokenization - #papers: 1 - taxonomies: ['wikidata_ai']
# term: text simplification - #papers: 1 - taxonomies: ['wikidata_ai']
# term: morphological parsing - #papers: 1 - taxonomies: ['wikidata_ai']
# term: chinese information processing - #papers: 1 - taxonomies: ['wikidata_ai']
# term: computer-based question classification - #papers: 1 - taxonomies: ['wikidata_ai']
# term: biomedical natural language processing - #papers: 1 - taxonomies: ['wikidata_ai']
# term: wikification - #papers: 1 - taxonomies: ['wikidata_ai']
# term: speaker verification - #papers: 1 - taxonomies: ['wikidata_ai']
# term: word segmentation - #papers: 1 - taxonomies: ['wikidata_ai']
# term: māori natural language processing - #papers: 1 - taxonomies: ['wikidata_ai']
# term: statistical natural language processing - #papers: 1 - taxonomies: ['wikidata_ai']
# term: connectionist expert system - #papers: 1 - taxonomies: ['wikidata_ai']
# term: emycin - #papers: 1 - taxonomies: ['wikidata_ai']
# term: diagnostic expert system - #papers: 1 - taxonomies: ['wikidata_ai']
# term: rule-based expert system - #papers: 1 - taxonomies: ['wikidata_ai']
# term: frame-based expert system - #papers: 1 - taxonomies: ['wikidata_ai']
# term: metaexpert system - #papers: 1 - taxonomies: ['wikidata_ai']
# term: monitoring expert system - #papers: 1 - taxonomies: ['wikidata_ai']
# term: planning expert system - #papers: 1 - taxonomies: ['wikidata_ai']
# term: group decision support systems - #papers: 1 - taxonomies: ['wikidata_ai']
# term: fordec - #papers: 1 - taxonomies: ['wikidata_ai']
# term: automated decision support system - #papers: 1 - taxonomies: ['wikidata_ai']
# term: ai diagnostics - #papers: 1 - taxonomies: ['wikidata_ai']
# term: clinical decision support system - #papers: 1 - taxonomies: ['wikidata_ai']
# term: intelligent decision support systems - #papers: 1 - taxonomies: ['wikidata_ai']
# term: marketing decision support system - #papers: 1 - taxonomies: ['wikidata_ai']
# term: spatial decision support system - #papers: 1 - taxonomies: ['wikidata_ai']
# term: q11668228 - #papers: 1 - taxonomies: ['wikidata_ai']
# term: sentiment analysis - #papers: 1 - taxonomies: ['wikidata_ai']
# term: metaheuristic - #papers: 1 - taxonomies: ['wikidata_ai']
# term: heuristic search algorithm - #papers: 1 - taxonomies: ['wikidata_ai']
# term: monte carlo algorithm - #papers: 1 - taxonomies: ['wikidata_ai']
# term: informed search algorithm - #papers: 1 - taxonomies: ['wikidata_ai']
# term: heuristic for determination of copyright status of a creator - #papers: 1 - taxonomies: ['wikidata_ai']
# term: droid - #papers: 1 - taxonomies: ['wikidata_ai']
# term: sentinel - #papers: 1 - taxonomies: ['wikidata_ai']
# term: mobile suit - #papers: 1 - taxonomies: ['wikidata_ai']
# term: haro - #papers: 1 - taxonomies: ['wikidata_ai']
# term: replicator - #papers: 1 - taxonomies: ['wikidata_ai']
# term: manhunters - #papers: 1 - taxonomies: ['wikidata_ai']
# term: thinking machines - #papers: 1 - taxonomies: ['wikidata_ai']
# term: egg pawn - #papers: 1 - taxonomies: ['wikidata_ai']
# term: positronic brain - #papers: 1 - taxonomies: ['wikidata_ai']
# term: exocomp - #papers: 1 - taxonomies: ['wikidata_ai']
# term: positronic robot - #papers: 1 - taxonomies: ['wikidata_ai']
# term: mobile armour - #papers: 1 - taxonomies: ['wikidata_ai']
# term: deros - #papers: 1 - taxonomies: ['wikidata_ai']
# term: q6087026 - #papers: 1 - taxonomies: ['wikidata_ai']
# term: transformer - #papers: 1 - taxonomies: ['wikidata_ai']
# term: robots in futurama - #papers: 1 - taxonomies: ['wikidata_ai']
# term: omnidroid - #papers: 1 - taxonomies: ['wikidata_ai']
# term: doombot - #papers: 1 - taxonomies: ['wikidata_ai']
# term: fictional android - #papers: 1 - taxonomies: ['wikidata_ai']
# term: leviathan - #papers: 1 - taxonomies: ['wikidata_ai']
# term: recorders - #papers: 1 - taxonomies: ['wikidata_ai']
# term: robot master - #papers: 1 - taxonomies: ['wikidata_ai']
# term: servbot - #papers: 1 - taxonomies: ['wikidata_ai']
# term: agent - #papers: 1 - taxonomies: ['wikidata_ai']
# term: five nights at freddy's animatronic - #papers: 1 - taxonomies: ['wikidata_ai']
# term: q117307251 - #papers: 1 - taxonomies: ['wikidata_ai']
# term: autonomous vehicle - #papers: 1 - taxonomies: ['wikidata_ai']
# term: battle droid - #papers: 1 - taxonomies: ['wikidata_ai']
# term: tri-droid - #papers: 1 - taxonomies: ['wikidata_ai']
# term: og-9 homing spider droid - #papers: 1 - taxonomies: ['wikidata_ai']
# term: ig-100 magnaguard - #papers: 1 - taxonomies: ['wikidata_ai']
# term: probe droid - #papers: 1 - taxonomies: ['wikidata_ai']
# term: q3932529 - #papers: 1 - taxonomies: ['wikidata_ai']
# term: q3977640 - #papers: 1 - taxonomies: ['wikidata_ai']
# term: droideka - #papers: 1 - taxonomies: ['wikidata_ai']
# term: q5551095 - #papers: 1 - taxonomies: ['wikidata_ai']
# term: crab droid - #papers: 1 - taxonomies: ['wikidata_ai']
# term: spider droids - #papers: 1 - taxonomies: ['wikidata_ai']
# term: q6138715 - #papers: 1 - taxonomies: ['wikidata_ai']
# term: buzz droid - #papers: 1 - taxonomies: ['wikidata_ai']
# term: droid starfighter - #papers: 1 - taxonomies: ['wikidata_ai']
# term: astromech droid - #papers: 1 - taxonomies: ['wikidata_ai']
# term: gnk power droid - #papers: 1 - taxonomies: ['wikidata_ai']
# term: q11680632 - #papers: 1 - taxonomies: ['wikidata_ai']
# term: super battle droid - #papers: 1 - taxonomies: ['wikidata_ai']
# term: protocol droid - #papers: 1 - taxonomies: ['wikidata_ai']
# term: q2313222 - #papers: 1 - taxonomies: ['wikidata_ai']
# term: optical character recognition - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: handwriting recognition - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: model-free reinforcement learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: deep reinforcement learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: multi-agent reinforcement learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: policy-gradient method - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: reinforcement learning from human feedback - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: rx-77-2 guncannon - #papers: 1 - taxonomies: ['wikidata_ai']
# term: ms-14a gelgoog - #papers: 1 - taxonomies: ['wikidata_ai']
# term: zaku - #papers: 1 - taxonomies: ['wikidata_ai']
# term: rx-178 gundam mk-ii - #papers: 1 - taxonomies: ['wikidata_ai']
# term: rx-79[g] gundam ground type - #papers: 1 - taxonomies: ['wikidata_ai']
# term: rx-75 guntank - #papers: 1 - taxonomies: ['wikidata_ai']
# term: gundam - #papers: 1 - taxonomies: ['wikidata_ai']
# term: msm-04 acguy - #papers: 1 - taxonomies: ['wikidata_ai']
# term: zaku i - #papers: 1 - taxonomies: ['wikidata_ai']
# term: ginn - #papers: 1 - taxonomies: ['wikidata_ai']
# term: gfas-x1 destroy gundam - #papers: 1 - taxonomies: ['wikidata_ai']
# term: amx-011 zaku iii - #papers: 1 - taxonomies: ['wikidata_ai']
# term: xm-x crossbone gundam - #papers: 1 - taxonomies: ['wikidata_ai']
# term: gt-9600 gundam leopard - #papers: 1 - taxonomies: ['wikidata_ai']
# term: gw-9800 gundam airmaster - #papers: 1 - taxonomies: ['wikidata_ai']
# term: gat-04 windam - #papers: 1 - taxonomies: ['wikidata_ai']
# term: ms-18e kämpfer - #papers: 1 - taxonomies: ['wikidata_ai']
# term: amx-003 gaza-c - #papers: 1 - taxonomies: ['wikidata_ai']
# term: ams-119 geara doga - #papers: 1 - taxonomies: ['wikidata_ai']
# term: ms-19 dolmel - #papers: 1 - taxonomies: ['wikidata_ai']
# term: ms-09r rick dom - #papers: 1 - taxonomies: ['wikidata_ai']
# term: rms-099 rick dias - #papers: 1 - taxonomies: ['wikidata_ai']
# term: transformable mobile suit - #papers: 1 - taxonomies: ['wikidata_ai']
# term: amx-109 capule - #papers: 1 - taxonomies: ['wikidata_ai']
# term: quantitative structure-activity relationship - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: proteochemometrics - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: quantitative structure–property relationship - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: human-form replicators - #papers: 1 - taxonomies: ['wikidata_ai']
# term: natural language inference - #papers: 1 - taxonomies: ['wikidata_ai']
# term: knowledge-intensive natural language understanding - #papers: 1 - taxonomies: ['wikidata_ai']
# term: independent component analysis - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: archetypal analysis - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: boosting - #papers: 2 - taxonomies: ['wikidata_ai', 'cso']
# term: q1351503 - #papers: 1 - taxonomies: ['wikidata_ai']
# term: greedy randomized adaptive search procedure - #papers: 1 - taxonomies: ['wikidata_ai']
# term: firefly algorithm - #papers: 1 - taxonomies: ['wikidata_ai']
# term: guided local search - #papers: 1 - taxonomies: ['wikidata_ai']
# term: iterated local search - #papers: 1 - taxonomies: ['wikidata_ai']
# term: variable neighborhood search - #papers: 1 - taxonomies: ['wikidata_ai']
# term: autocomplete - #papers: 1 - taxonomies: ['wikidata_ai']
# term: parody generator - #papers: 1 - taxonomies: ['wikidata_ai']
# term: document classification - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: multiclass classification - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: binary classification - #papers: 3 - taxonomies: ['wikidata_ai', 'wikidata_ml', 'cso']
# term: sentence boundary disambiguation - #papers: 1 - taxonomies: ['wikidata_ai']
# term: decompounding - #papers: 1 - taxonomies: ['wikidata_ai']
# term: ma-05 bigro - #papers: 1 - taxonomies: ['wikidata_ai']
# term: ts-ma2mod.00 moebius zero - #papers: 1 - taxonomies: ['wikidata_ai']
# term: orx-005 gaplant - #papers: 1 - taxonomies: ['wikidata_ai']
# term: nrx-055 baund doc - #papers: 1 - taxonomies: ['wikidata_ai']
# term: man-03 braw bro - #papers: 1 - taxonomies: ['wikidata_ai']
# term: deep transfer learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: isomap - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: autobot - #papers: 1 - taxonomies: ['wikidata_ai']
# term: decepticon - #papers: 1 - taxonomies: ['wikidata_ai']
# term: maximal - #papers: 1 - taxonomies: ['wikidata_ai']
# term: predacon - #papers: 1 - taxonomies: ['wikidata_ai']
# term: vehicon - #papers: 1 - taxonomies: ['wikidata_ai']
# term: gobots - #papers: 1 - taxonomies: ['wikidata_ai']
# term: laserbeak - #papers: 1 - taxonomies: ['wikidata_ai']
# term: headmaster - #papers: 1 - taxonomies: ['wikidata_ai']
# term: combiner (transformers) - #papers: 1 - taxonomies: ['wikidata_ai']
# term: triple changer - #papers: 1 - taxonomies: ['wikidata_ai']
# term: recon team - #papers: 1 - taxonomies: ['wikidata_ai']
# term: slugfest - #papers: 1 - taxonomies: ['wikidata_ai']
# term: throttlebots - #papers: 1 - taxonomies: ['wikidata_ai']
# term: flareup - #papers: 1 - taxonomies: ['wikidata_ai']
# term: cassette robots - #papers: 1 - taxonomies: ['wikidata_ai']
# term: mean field particle methods - #papers: 1 - taxonomies: ['wikidata_ai']
# term: sparse dictionary learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: replicant - #papers: 1 - taxonomies: ['wikidata_ai']
# term: life model decoy - #papers: 1 - taxonomies: ['wikidata_ai']
# term: nindroid - #papers: 1 - taxonomies: ['wikidata_ai']
# term: fictional gynoid - #papers: 1 - taxonomies: ['wikidata_ai']
# term: artificial immune system - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: genetic algorithm - #papers: 2 - taxonomies: ['wikidata_ai', 'cso']
# term: local search - #papers: 1 - taxonomies: ['wikidata_ai']
# term: autonomous underwater vehicle - #papers: 1 - taxonomies: ['wikidata_ai']
# term: autonomous car - #papers: 1 - taxonomies: ['wikidata_ai']
# term: autonomous truck - #papers: 1 - taxonomies: ['wikidata_ai']
# term: autonomous bus - #papers: 1 - taxonomies: ['wikidata_ai']
# term: autonomous aircraft - #papers: 1 - taxonomies: ['wikidata_ai']
# term: autonomous watercraft - #papers: 1 - taxonomies: ['wikidata_ai']
# term: autonomous spacecraft - #papers: 1 - taxonomies: ['wikidata_ai']
# term: q9051700 - #papers: 1 - taxonomies: ['wikidata_ai']
# term: aerialbots - #papers: 1 - taxonomies: ['wikidata_ai']
# term: dinobot - #papers: 1 - taxonomies: ['wikidata_ai']
# term: air raid - #papers: 1 - taxonomies: ['wikidata_ai']
# term: inferno - #papers: 1 - taxonomies: ['wikidata_ai']
# term: wreckers - #papers: 1 - taxonomies: ['wikidata_ai']
# term: afterburners - #papers: 1 - taxonomies: ['wikidata_ai']
# term: ricochet - #papers: 1 - taxonomies: ['wikidata_ai']
# term: micr - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: intelligent character recognition - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: optical braille recognition - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: hill climbing - #papers: 1 - taxonomies: ['wikidata_ai']
# term: genetic algorithm scheduling - #papers: 1 - taxonomies: ['wikidata_ai']
# term: interactive evolutionary computation - #papers: 1 - taxonomies: ['wikidata_ai']
# term: underwater glider - #papers: 1 - taxonomies: ['wikidata_ai']
# term: remus - #papers: 1 - taxonomies: ['wikidata_ai']
# ...
# term: process mining - #papers: 1 - taxonomies: ['cso']
# term: naive bayes - #papers: 1 - taxonomies: ['cso']
# term: classification rules - #papers: 1 - taxonomies: ['cso']
# term: formal approach - #papers: 1 - taxonomies: ['cso']
# term: formal framework - #papers: 1 - taxonomies: ['cso']
# term: tutoring system - #papers: 1 - taxonomies: ['cso']
# term: computer assisted - #papers: 1 - taxonomies: ['cso']
# term: exact inference - #papers: 1 - taxonomies: ['cso']
# term: inference - #papers: 1 - taxonomies: ['cso']
# term: scada systems - #papers: 1 - taxonomies: ['cso']
# term: in-process - #papers: 1 - taxonomies: ['cso']
# term: process-oriented - #papers: 1 - taxonomies: ['cso']
# term: group members - #papers: 1 - taxonomies: ['cso']
# term: user interests - #papers: 1 - taxonomies: ['cso']
# term: user profiling - #papers: 1 - taxonomies: ['cso']
# term: taxation - #papers: 1 - taxonomies: ['cso']
# term: computer aided - #papers: 1 - taxonomies: ['cso']
# term: reinforcement learning method - #papers: 1 - taxonomies: ['cso']
# term: action spaces - #papers: 1 - taxonomies: ['cso']
# term: model free - #papers: 1 - taxonomies: ['cso']
# term: value function approximation - #papers: 1 - taxonomies: ['cso']
# term: mutual informations - #papers: 1 - taxonomies: ['cso']
# term: mutual information - #papers: 1 - taxonomies: ['cso']
# term: first order logic - #papers: 1 - taxonomies: ['cso']
# term: first-order logic - #papers: 1 - taxonomies: ['cso']
# term: combinatorial auctions - #papers: 1 - taxonomies: ['cso']
# term: combinatorial auction - #papers: 1 - taxonomies: ['cso']
# term: modal logic - #papers: 1 - taxonomies: ['cso']
# term: modal logics - #papers: 1 - taxonomies: ['cso']
# term: high dimensional data - #papers: 1 - taxonomies: ['cso']
# term: high-dimensional data - #papers: 1 - taxonomies: ['cso']
# term: ensemble classifiers - #papers: 1 - taxonomies: ['cso']
# term: ensemble classifier - #papers: 1 - taxonomies: ['cso']
# term: descriptors - #papers: 1 - taxonomies: ['cso']
# term: descriptor - #papers: 1 - taxonomies: ['cso']
# term: visual feature - #papers: 1 - taxonomies: ['cso']
# term: visual features - #papers: 1 - taxonomies: ['cso']
# term: formal model - #papers: 1 - taxonomies: ['cso']
# term: formal models - #papers: 1 - taxonomies: ['cso']
# term: classifier ensembles - #papers: 1 - taxonomies: ['cso']
# term: classifier ensemble - #papers: 1 - taxonomies: ['cso']
# term: partially observable markov decision process - #papers: 1 - taxonomies: ['cso']
# term: partially observable markov decision processes - #papers: 1 - taxonomies: ['cso']
# term: memetic algorithms - #papers: 1 - taxonomies: ['cso']
# term: memetic algorithm - #papers: 1 - taxonomies: ['cso']
# term: matrix factorizations - #papers: 1 - taxonomies: ['cso']
# term: matrix factorization - #papers: 1 - taxonomies: ['cso']
# term: natural languages - #papers: 1 - taxonomies: ['cso']
# term: natural language - #papers: 1 - taxonomies: ['cso']
# term: coalition formations - #papers: 1 - taxonomies: ['cso']
# term: coalition formation - #papers: 1 - taxonomies: ['cso']
# term: data stream - #papers: 1 - taxonomies: ['cso']
# term: data streams - #papers: 1 - taxonomies: ['cso']
# term: personalization - #papers: 1 - taxonomies: ['cso']
# term: personalizations - #papers: 1 - taxonomies: ['cso']
# term: mobile agents - #papers: 1 - taxonomies: ['cso']
# term: mobile agent - #papers: 1 - taxonomies: ['cso']
# term: evolutionary computations - #papers: 1 - taxonomies: ['cso']
# term: computing with words - #papers: 1 - taxonomies: ['cso']
# term: computing with word %28cww%29 - #papers: 1 - taxonomies: ['cso']
# term: estimation of distribution algorithms - #papers: 1 - taxonomies: ['cso']
# term: estimation of distribution algorithm - #papers: 1 - taxonomies: ['cso']
# term: distributed environments - #papers: 1 - taxonomies: ['cso']
# term: distributed environment - #papers: 1 - taxonomies: ['cso']
# term: value functions - #papers: 1 - taxonomies: ['cso']
# term: value function - #papers: 1 - taxonomies: ['cso']
# term: personalized service - #papers: 1 - taxonomies: ['cso']
# term: personalized services - #papers: 1 - taxonomies: ['cso']
# term: evaluation models - #papers: 1 - taxonomies: ['cso']
# term: evaluation model - #papers: 1 - taxonomies: ['cso']
# term: binary classifiers - #papers: 1 - taxonomies: ['cso']
# term: agent based - #papers: 1 - taxonomies: ['cso']
# term: agent-based - #papers: 1 - taxonomies: ['cso']
# term: probabilistic models - #papers: 1 - taxonomies: ['cso']
# term: probabilistic model - #papers: 1 - taxonomies: ['cso']
# term: unified medical language system - #papers: 1 - taxonomies: ['cso']
# term: unified medical language systems - #papers: 1 - taxonomies: ['cso']
# term: user profile - #papers: 1 - taxonomies: ['cso']
# term: user profiles - #papers: 1 - taxonomies: ['cso']
# term: cross validation - #papers: 1 - taxonomies: ['cso']
# term: cross-validation - #papers: 1 - taxonomies: ['cso']
# term: satisfiability problems - #papers: 1 - taxonomies: ['cso']
# term: satisfiability problem - #papers: 1 - taxonomies: ['cso']
# term: self organizing - #papers: 1 - taxonomies: ['cso']
# term: self-organizing - #papers: 1 - taxonomies: ['cso']
# term: hierarchical structures - #papers: 1 - taxonomies: ['cso']
# term: hierarchical structure - #papers: 1 - taxonomies: ['cso']
# term: distributed architecture - #papers: 1 - taxonomies: ['cso']
# term: distributed architectures - #papers: 1 - taxonomies: ['cso']
# term: agent-based systems - #papers: 1 - taxonomies: ['cso']
# term: agent-based system - #papers: 1 - taxonomies: ['cso']
# term: domain knowledge - #papers: 1 - taxonomies: ['cso']
# term: domain experts - #papers: 1 - taxonomies: ['cso']
# term: human robot interaction - #papers: 1 - taxonomies: ['cso']
# term: human-robot interaction - #papers: 1 - taxonomies: ['cso']
# term: human robot interactions - #papers: 1 - taxonomies: ['cso']
# term: markov decision process %28mdp%29 - #papers: 1 - taxonomies: ['cso']
# term: markov decision processes - #papers: 1 - taxonomies: ['cso']
# term: markov decision process - #papers: 1 - taxonomies: ['cso']
# term: computer-aided diagnosis %28cad%29 - #papers: 1 - taxonomies: ['cso']
# term: computer aided diagnosis - #papers: 1 - taxonomies: ['cso']
# term: computer-aided diagnosis - #papers: 1 - taxonomies: ['cso']
# term: student modeling - #papers: 1 - taxonomies: ['cso']
# term: student models - #papers: 1 - taxonomies: ['cso']
# term: student model - #papers: 1 - taxonomies: ['cso']
# term: knowledge base - #papers: 1 - taxonomies: ['cso']
# term: knowledge bases - #papers: 1 - taxonomies: ['cso']
# term: cognitive modeling - #papers: 1 - taxonomies: ['cso']
# term: cognitive model - #papers: 1 - taxonomies: ['cso']
# term: cognitive models - #papers: 1 - taxonomies: ['cso']
# term: supervised machine learning - #papers: 1 - taxonomies: ['cso']
# term: background knowledge - #papers: 1 - taxonomies: ['cso']
# term: automatic classification - #papers: 1 - taxonomies: ['cso']
# term: class labels - #papers: 1 - taxonomies: ['cso']
# term: epistemic logic - #papers: 1 - taxonomies: ['cso']
# term: decision making%2c computer-assisted - #papers: 1 - taxonomies: ['cso']
# term: swarm robotics - #papers: 1 - taxonomies: ['cso']
# term: stigmergy - #papers: 1 - taxonomies: ['cso']
# term: word similarity - #papers: 1 - taxonomies: ['cso']
# term: fuzzy-neural - #papers: 1 - taxonomies: ['cso']
# term: systems integration - #papers: 1 - taxonomies: ['cso']
# term: textual data - #papers: 1 - taxonomies: ['cso']
# term: biomedical literature - #papers: 1 - taxonomies: ['cso']
# term: text data - #papers: 1 - taxonomies: ['cso']
# term: continuous data - #papers: 1 - taxonomies: ['cso']
# term: extracting information - #papers: 1 - taxonomies: ['cso']
# term: free texts - #papers: 1 - taxonomies: ['cso']
# term: player experience - #papers: 1 - taxonomies: ['cso']
# term: game designers - #papers: 1 - taxonomies: ['cso']
# term: affective state - #papers: 1 - taxonomies: ['cso']
# term: natural language text - #papers: 1 - taxonomies: ['cso']
# term: knowledge engineers - #papers: 1 - taxonomies: ['cso']
# term: single-agent - #papers: 1 - taxonomies: ['cso']
# term: agent model - #papers: 1 - taxonomies: ['cso']
# term: initial solution - #papers: 1 - taxonomies: ['cso']
# term: numerical analysis%2c computer-assisted - #papers: 1 - taxonomies: ['cso']
# term: cbr - #papers: 1 - taxonomies: ['cso']
# term: cbr systems - #papers: 1 - taxonomies: ['cso']
# term: case-based reasoning approaches - #papers: 1 - taxonomies: ['cso']
# term: similar case - #papers: 1 - taxonomies: ['cso']
# term: rule base - #papers: 1 - taxonomies: ['cso']
# term: automatic evaluation - #papers: 1 - taxonomies: ['cso']
# term: situation awareness - #papers: 1 - taxonomies: ['cso']
# term: user preferences - #papers: 1 - taxonomies: ['cso']
# term: latent variable models - #papers: 1 - taxonomies: ['cso']
# term: boolean satisfiability - #papers: 1 - taxonomies: ['cso']
# term: solution concepts - #papers: 1 - taxonomies: ['cso']
# term: exploration and exploitation - #papers: 1 - taxonomies: ['cso']
# term: candidate solution - #papers: 1 - taxonomies: ['cso']
# term: memetic - #papers: 1 - taxonomies: ['cso']
# term: k-nn classifier - #papers: 1 - taxonomies: ['cso']
# term: k-nearest neighbor classifier - #papers: 1 - taxonomies: ['cso']
# term: low-dimensional spaces - #papers: 1 - taxonomies: ['cso']
# term: demonstrations - #papers: 1 - taxonomies: ['cso']
# term: re-planning - #papers: 1 - taxonomies: ['cso']
# term: markov logic networks - #papers: 1 - taxonomies: ['cso']
# term: sat-solving - #papers: 1 - taxonomies: ['cso']
# term: dempster-shafer theory of evidence - #papers: 1 - taxonomies: ['cso']
# term: sat problems - #papers: 1 - taxonomies: ['cso']
# term: pedagogical agents - #papers: 1 - taxonomies: ['cso']
# term: intelligent tutors - #papers: 1 - taxonomies: ['cso']
# term: action language - #papers: 1 - taxonomies: ['cso']
# term: low-dimensional manifolds - #papers: 1 - taxonomies: ['cso']
# term: k-nn - #papers: 1 - taxonomies: ['cso']
# term: high-dimensional feature space - #papers: 1 - taxonomies: ['cso']
# term: multi-class problems - #papers: 1 - taxonomies: ['cso']
# term: multi-class classifier - #papers: 1 - taxonomies: ['cso']
# term: sequential decision making - #papers: 1 - taxonomies: ['cso']
# term: spatial objects - #papers: 1 - taxonomies: ['cso']
# term: user information - #papers: 1 - taxonomies: ['cso']
# term: pair-wise comparison - #papers: 1 - taxonomies: ['cso']
# term: preference information - #papers: 1 - taxonomies: ['cso']
# term: computer integrated manufacturing - #papers: 1 - taxonomies: ['cso']
# term: technical indicator - #papers: 1 - taxonomies: ['cso']
# term: trading systems - #papers: 1 - taxonomies: ['cso']
# term: bayesian networks %28bns%29 - #papers: 1 - taxonomies: ['cso']
# term: bayesian network classifiers - #papers: 1 - taxonomies: ['cso']
# term: probabilistic modeling - #papers: 1 - taxonomies: ['cso']
# term: solution accuracy - #papers: 1 - taxonomies: ['cso']
# term: electric fault location - #papers: 1 - taxonomies: ['cso']
# term: curse of dimensionality - #papers: 1 - taxonomies: ['cso']
# term: programming framework - #papers: 1 - taxonomies: ['cso']
# term: self-organize - #papers: 1 - taxonomies: ['cso']
# term: proof system - #papers: 1 - taxonomies: ['cso']
# term: traffic networks - #papers: 1 - taxonomies: ['cso']
# term: expectation propagation - #papers: 1 - taxonomies: ['cso']
# term: rule engine - #papers: 1 - taxonomies: ['cso']
# term: dialogue - #papers: 1 - taxonomies: ['cso']
# term: business decisions - #papers: 1 - taxonomies: ['cso']
# term: proof search - #papers: 1 - taxonomies: ['cso']
# term: continuous state - #papers: 1 - taxonomies: ['cso']
# term: concept drifts - #papers: 1 - taxonomies: ['cso']
# term: concept drift - #papers: 1 - taxonomies: ['cso']
# term: embodied agent - #papers: 1 - taxonomies: ['cso']
# term: embodied agents - #papers: 1 - taxonomies: ['cso']
# term: latent variable - #papers: 1 - taxonomies: ['cso']
# term: latent variables - #papers: 1 - taxonomies: ['cso']
# term: decision support techniques - #papers: 1 - taxonomies: ['cso']
# term: decision support systems%2c clinical - #papers: 1 - taxonomies: ['cso']
# term: ordered weighted averaging - #papers: 1 - taxonomies: ['cso']
# term: ordered weighted averaging operator - #papers: 1 - taxonomies: ['cso']
# term: dynamic environments - #papers: 1 - taxonomies: ['cso']
# term: dynamic environment - #papers: 1 - taxonomies: ['cso']
# term: random projections - #papers: 1 - taxonomies: ['cso']
# term: random projection - #papers: 1 - taxonomies: ['cso']
# term: information content - #papers: 1 - taxonomies: ['cso']
# term: information contents - #papers: 1 - taxonomies: ['cso']
# term: binary classification problems - #papers: 1 - taxonomies: ['cso']
# term: high-quality solutions - #papers: 1 - taxonomies: ['cso']
# term: combining classifiers - #papers: 1 - taxonomies: ['cso']
# term: casebased reasonings %28cbr%29 - #papers: 1 - taxonomies: ['cso']
# term: user activity - #papers: 1 - taxonomies: ['cso']
# term: points of interest - #papers: 1 - taxonomies: ['cso']
# term: supervised classifiers - #papers: 1 - taxonomies: ['cso']
# term: appearance modeling - #papers: 1 - taxonomies: ['cso']
# term: domain theory - #papers: 1 - taxonomies: ['cso']
# term: crossover operations - #papers: 1 - taxonomies: ['cso']
# term: learning from demonstration - #papers: 1 - taxonomies: ['cso']
# term: decision models - #papers: 1 - taxonomies: ['cso']
# term: decision model - #papers: 1 - taxonomies: ['cso']
# term: document-processing - #papers: 1 - taxonomies: ['cso']
# term: document processing - #papers: 1 - taxonomies: ['cso']
# term: non-stationary environment - #papers: 1 - taxonomies: ['cso']
# term: evaluation system - #papers: 1 - taxonomies: ['cso']
# term: theoretical result - #papers: 1 - taxonomies: ['cso']
# term: artificial intelligence@en  - #papers: 1 - taxonomies: ['cso']
# term: cso#topic - #papers: 2 - taxonomies: ['cso']
# term: distributed artificial intelligence@en  - #papers: 1 - taxonomies: ['cso']
# term: game theory - #papers: 1 - taxonomies: ['cso']
# term: machine learning techniques - #papers: 1 - taxonomies: ['cso']
# term: machine learning methods - #papers: 1 - taxonomies: ['cso']
# term: machine learning algorithms - #papers: 1 - taxonomies: ['cso']
# term: genetic algorithm %28ga%29 - #papers: 1 - taxonomies: ['cso']
# term: genetic algorithms - #papers: 1 - taxonomies: ['cso']
# term: intelligent systems - #papers: 1 - taxonomies: ['cso']
# term: machine learnings - #papers: 1 - taxonomies: ['cso']
# term: multi agent system - #papers: 1 - taxonomies: ['cso']
# term: multiagent system - #papers: 1 - taxonomies: ['cso']
# term: swarm intelligence - #papers: 1 - taxonomies: ['cso']
# term: nlp - #papers: 1 - taxonomies: ['cso']
# term: commonsense - #papers: 1 - taxonomies: ['cso']
# term: common-sense - #papers: 1 - taxonomies: ['cso']
# term: commonsense reasoning - #papers: 1 - taxonomies: ['cso']
# term: common-sense reasoning - #papers: 1 - taxonomies: ['cso']
# term: common-sense computing - #papers: 1 - taxonomies: ['cso']
# term: commonsense computing - #papers: 1 - taxonomies: ['cso']
# term: common sense - #papers: 1 - taxonomies: ['cso']
# term: ambient intelligent - #papers: 1 - taxonomies: ['cso']
# term: bayesian approaches - #papers: 1 - taxonomies: ['cso']
# term: bayesian approach - #papers: 1 - taxonomies: ['cso']
# term: bayesian - #papers: 1 - taxonomies: ['cso']
# term: bayesian model - #papers: 1 - taxonomies: ['cso']
# term: bayesian models - #papers: 1 - taxonomies: ['cso']
# term: bayesian method - #papers: 1 - taxonomies: ['cso']
# term: bayesian frameworks - #papers: 1 - taxonomies: ['cso']
# term: bayesian framework - #papers: 1 - taxonomies: ['cso']
# term: bayesian methods - #papers: 1 - taxonomies: ['cso']
# term: artificial intelligence - #papers: 2 - taxonomies: ['cso']
# term: q11660 - #papers: 1 - taxonomies: ['cso']
# term: q3153007 - #papers: 1 - taxonomies: ['cso']
# term: m.0mkz - #papers: 1 - taxonomies: ['cso']
# term: m.01jgvl - #papers: 1 - taxonomies: ['cso']
# term: mx4rvvi4wjwpebgdrcn5y29yca - #papers: 1 - taxonomies: ['cso']
# term: 2777200204 - #papers: 1 - taxonomies: ['cso']

# %% [markdown]
# ### Paper support for wikidata

# %%
import sys
from SPARQLWrapper import SPARQLWrapper, JSON
import json

# %%
endpoint_url = "https://query.wikidata.org/sparql"

# %%
def get_results(endpoint_url, query):
    user_agent = "WDQS-example Python/%s.%s" % (sys.version_info[0], sys.version_info[1])
    # TODO adjust user agent; see https://w.wiki/CX6
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    return sparql.query().convert()

# %%
with open('query_ai2.json', 'r') as f:
    wikidata_ml = json.load(f)
for ml in wikidata_ml:
    mainclass = ml['aiclass'].split('/')[-1]
    mainclassLabel = ml['aiclassLabel'].lower()

    query_ml_related = query_ml = """select ?tool ?toolLabel ?paper ?paperLabel where {
      # ?paper wdt:P921 wd:%s .
      # ?tool wdt:P31 wd:Q188860 .
      # ?tool wdt:P1343 ?paper .
      SERVICE wikibase:label { bd:serviceParam wikibase:language "en" }}
    """ % (mainclass)
    results_ml = get_results(endpoint_url, query_ml_related)
    
    for result_ml in results_ml["results"]["bindings"]:
        term_count[mainclassLabel]['#papers'] += 1
    
    query_ml_related = query_ml = """select ?tool ?toolLabel where {
      # ?tool wdt:P366 wd:%s .
      # ?tool wdt:P31 wd:Q188860 .
      SERVICE wikibase:label { bd:serviceParam wikibase:language "en" }}
    """ % (mainclass)
    results_ml1 = get_results(endpoint_url, query_ml_related)
    for ind, result_ml1 in enumerate(results_ml1["results"]["bindings"]):
        term_count[mainclassLabel]['#papers'] += 1
    count = len(results_ml1["results"]["bindings"]) + len(results_ml1["results"]["bindings"])
    print(f'{mainclassLabel} - {count}')
# Out:
# machine learning - 14
# natural language processing - 2
# expert system - 0
# decision support system - 0
# computational intelligence - 0
# affective computing - 0
# evolutionary computation - 0
# knowledge engineering - 0
# heuristic algorithm - 0
# automated planning and scheduling - 0
# distributed artificial intelligence - 0
# knowledge representation and reasoning - 0
# self-management - 0
# applications of artificial intelligence - 0
# symbolic artificial intelligence - 0
# neurorobotics - 0
# intelligent robotics - 0
# fictional robot - 0
# artificial intelligence in fiction - 0
# artificial empathy - 0
# artificial intelligence in healthcare - 0
# explainable ai - 0
# federated learning - 0
# multimodal sentiment analysis - 0
# artificial intelligence in wikimedia projects - 0
# quantum artificial intelligence - 0
# artificial chemist - 0
# associatron - 0
# automated music production - 0
# autonomous navigation - 0
# green ai - 0
# red ai - 0
# ethical artificial intelligence - 0
# responsible ai - 0
# prompt engineering - 0
# vision and language - 0
# artificial intelligence in material science - 0
# neuro-symbolic ai - 0
# strong ai and weak ai - 0
# applied artificial intelligence - 0
# machine unlearning - 0
# autonomous technologies - 0
# explanation-based learning - 0
# pattern recognition - 0
# hierarchical temporal memory - 0
# reinforcement learning - 0
# chemometrics - 0
# unsupervised learning - 0
# statistical classification - 0
# transfer learning - 0
# meta-learning - 0
# multi-task learning - 0
# nonlinear dimensionality reduction - 0
# offline learning - 0
# one-shot learning - 0
# online machine learning - 0
# preference learning - 0
# robot learning - 0
# statistical relational learning - 0
# structured prediction - 0
# feature learning - 0
# quantum machine learning - 0
# adversarial machine learning - 0
# multiple kernel learning - 0
# multimodal learning - 0
# m-theory - 0
# rule-based machine learning - 0
# incremental learning - 0
# machine learning in bioinformatics - 0
# sequence-to-sequence learning - 0
# automated machine learning - 0
# image-to-image translation - 0
# interactive machine learning - 0
# end-to-end learning - 0
# knowledge distillation - 0
# self-supervised learning - 2
# machine learning in physics - 0
# zero-shot learning - 0
# gossip learning - 0
# declarative machine learning - 0
# byy harmony learning - 0
# few-shot learning - 0
# pathways - 0
# semi-supervised and unsupervised learning - 0
# personalized machine learning - 0
# continual learning - 0
# imbalanced learning - 0
# speech recognition - 2
# natural language understanding - 0
# part-of-speech tagging - 0
# natural language generation - 0
# morphological analysis - 0
# text segmentation - 0
# tokenization - 0
# text simplification - 0
# morphological parsing - 0
# chinese information processing - 0
# computer-based question classification - 0
# biomedical natural language processing - 0
# wikification - 0
# speaker verification - 0
# word segmentation - 0
# māori natural language processing - 0
# statistical natural language processing - 0
# connectionist expert system - 0
# emycin - 0
# diagnostic expert system - 0
# rule-based expert system - 0
# frame-based expert system - 0
# metaexpert system - 0
# monitoring expert system - 0
# planning expert system - 0
# group decision support systems - 0
# fordec - 0
# automated decision support system - 0
# ai diagnostics - 0
# clinical decision support system - 0
# intelligent decision support systems - 0
# marketing decision support system - 0
# spatial decision support system - 0
# q11668228 - 0
# sentiment analysis - 0
# metaheuristic - 0
# heuristic search algorithm - 0
# monte carlo algorithm - 0
# informed search algorithm - 0
# heuristic for determination of copyright status of a creator - 0
# droid - 0
# sentinel - 0
# mobile suit - 0
# haro - 0
# replicator - 0
# manhunters - 0
# thinking machines - 0
# egg pawn - 0
# positronic brain - 0
# exocomp - 0
# positronic robot - 0
# mobile armour - 0
# deros - 0
# q6087026 - 0
# transformer - 0
# robots in futurama - 0
# omnidroid - 0
# doombot - 0
# fictional android - 0
# leviathan - 0
# recorders - 0
# robot master - 0
# servbot - 0
# agent - 0
# five nights at freddy's animatronic - 0
# q117307251 - 0
# few-shot learning - 0
# autonomous vehicle - 0
# battle droid - 0
# tri-droid - 0
# og-9 homing spider droid - 0
# ig-100 magnaguard - 0
# probe droid - 0
# q3932529 - 0
# q3977640 - 0
# droideka - 0
# q5551095 - 0
# crab droid - 0
# spider droids - 0
# q6138715 - 0
# buzz droid - 0
# droid starfighter - 0
# astromech droid - 0
# gnk power droid - 0
# q11680632 - 0
# super battle droid - 0
# protocol droid - 0
# q2313222 - 0
# optical character recognition - 4
# handwriting recognition - 0
# model-free reinforcement learning - 0
# deep reinforcement learning - 0
# multi-agent reinforcement learning - 0
# policy-gradient method - 0
# reinforcement learning from human feedback - 0
# rx-77-2 guncannon - 0
# ms-14a gelgoog - 0
# zaku - 0
# rx-178 gundam mk-ii - 0
# rx-79[g] gundam ground type - 0
# rx-75 guntank - 0
# gundam - 0
# msm-04 acguy - 0
# zaku i - 0
# ginn - 0
# gfas-x1 destroy gundam - 0
# amx-011 zaku iii - 0
# xm-x crossbone gundam - 0
# gt-9600 gundam leopard - 0
# gw-9800 gundam airmaster - 0
# gat-04 windam - 0
# ms-18e kämpfer - 0
# amx-003 gaza-c - 0
# ams-119 geara doga - 0
# ms-19 dolmel - 0
# ms-09r rick dom - 0
# rms-099 rick dias - 0
# transformable mobile suit - 0
# amx-109 capule - 0
# quantitative structure-activity relationship - 0
# proteochemometrics - 0
# quantitative structure–property relationship - 0
# human-form replicators - 0
# natural language inference - 0
# knowledge-intensive natural language understanding - 0
# independent component analysis - 0
# archetypal analysis - 0
# boosting - 0
# q1351503 - 0
# greedy randomized adaptive search procedure - 0
# firefly algorithm - 0
# guided local search - 0
# iterated local search - 0
# variable neighborhood search - 0
# autocomplete - 0
# parody generator - 0
# document classification - 0
# multiclass classification - 0
# binary classification - 0
# sentence boundary disambiguation - 0
# decompounding - 0
# ma-05 bigro - 0
# ts-ma2mod.00 moebius zero - 0
# orx-005 gaplant - 0
# nrx-055 baund doc - 0
# man-03 braw bro - 0
# deep transfer learning - 0
# isomap - 0
# autobot - 0
# decepticon - 0
# maximal - 0
# predacon - 0
# vehicon - 0
# gobots - 0
# laserbeak - 0
# headmaster - 0
# combiner (transformers) - 0
# triple changer - 0
# recon team - 0
# slugfest - 0
# throttlebots - 0
# flareup - 0
# cassette robots - 0
# mean field particle methods - 0
# sparse dictionary learning - 0
# replicant - 0
# life model decoy - 0
# nindroid - 0
# fictional gynoid - 0
# artificial immune system - 0
# active learning - 0
# genetic algorithm - 0
# local search - 0
# autonomous underwater vehicle - 0
# autonomous car - 0
# autonomous truck - 0
# autonomous bus - 0
# autonomous aircraft - 0
# autonomous watercraft - 0
# autonomous spacecraft - 0
# q9051700 - 0
# aerialbots - 0
# dinobot - 0
# air raid - 0
# inferno - 0
# wreckers - 0
# afterburners - 0
# ricochet - 0
# micr - 0
# intelligent character recognition - 0
# optical braille recognition - 0
# hill climbing - 0
# genetic algorithm scheduling - 0
# interactive evolutionary computation - 0
# underwater glider - 0
# remus - 0
# email filtering - 0
# waymo - 0
# renault ez-go - 0
# renault ez-ultimo - 0
# navya autonom cab - 0
# apolong - 0
# yandex self-driving car - 0
# command-line completion - 0
# intelligent code completion - 0
# shockwave - 0
# insecticons - 0
# duocons - 0
# over-run - 0
# overload - 0
# horrorcons - 0
# beam search - 0
# local beam search - 0
# mini-con - 0
# paper generator - 0
# q3998527 - 0
# q-learning - 0
# proximal policy optimization - 0
# trust region policy optimization - 0
# challenge–response spam filtering - 0
# huntington ingalls seaglider m1 - 0
# liberdade class underwater glider - 0

# %%
with open('query_ml1.json', 'r') as f:
    wikidata_ml = json.load(f)
for ml in wikidata_ml:
    mainclass = ml['aiclass'].split('/')[-1]
    mainclassLabel = ml['aiclassLabel'].lower()
    #print(mainclassLabel + '\n')

    query_ml_related = query_ml = """select ?tool ?toolLabel ?paper ?paperLabel where {
      # ?paper wdt:P921 wd:%s .
      SERVICE wikibase:label { bd:serviceParam wikibase:language "en" }}
    """ % (mainclass)
    results_ml = get_results(endpoint_url, query_ml_related)
    for result_ml in results_ml["results"]["bindings"]:
        term_count[mainclassLabel]['#papers'] += 1
    break
    query_ml_related = query_ml = """select ?tool ?toolLabel where {
      # ?tool wdt:P366 wd:%s .
      # ?tool wdt:P31 wd:Q188860 .
      SERVICE wikibase:label { bd:serviceParam wikibase:language "en" }}
    """ % (mainclass)
    results_ml1 = get_results(endpoint_url, query_ml_related)
    for ind, result_ml1 in enumerate(results_ml1["results"]["bindings"]):
        term_count[mainclassLabel]['#papers'] += 1
    count = len(results_ml1["results"]["bindings"]) + len(results_ml1["results"]["bindings"])
    print(f'{mainclassLabel} - {count}')
# Out:
# explanation-based learning - 0
# pattern recognition - 0
# hierarchical temporal memory - 0
# reinforcement learning - 0
# chemometrics - 0
# unsupervised learning - 0
# statistical classification - 0
# transfer learning - 0
# meta-learning - 0
# multi-task learning - 0
# nonlinear dimensionality reduction - 0
# offline learning - 0
# one-shot learning - 0
# online machine learning - 0
# preference learning - 0
# robot learning - 0
# statistical relational learning - 0
# structured prediction - 0
# feature learning - 0
# quantum machine learning - 0
# adversarial machine learning - 0
# multiple kernel learning - 0
# multimodal learning - 0
# m-theory - 0
# rule-based machine learning - 0
# incremental learning - 0
# machine learning in bioinformatics - 0
# sequence-to-sequence learning - 0
# automated machine learning - 0
# image-to-image translation - 0
# federated learning - 0
# interactive machine learning - 0
# end-to-end learning - 0
# knowledge distillation - 0
# self-supervised learning - 2
# machine learning in physics - 0
# zero-shot learning - 0
# gossip learning - 0
# declarative machine learning - 0
# byy harmony learning - 0
# few-shot learning - 0
# pathways - 0
# semi-supervised and unsupervised learning - 0
# personalized machine learning - 0
# continual learning - 0
# imbalanced learning - 0
# optical character recognition - 4
# handwriting recognition - 0
# model-free reinforcement learning - 0
# deep reinforcement learning - 0
# multi-agent reinforcement learning - 0
# policy-gradient method - 0
# reinforcement learning from human feedback - 0
# quantitative structure-activity relationship - 0
# proteochemometrics - 0
# quantitative structure–property relationship - 0
# independent component analysis - 0
# archetypal analysis - 0
# document classification - 0
# multiclass classification - 0
# binary classification - 0
# deep transfer learning - 0
# isomap - 0
# sparse dictionary learning - 0
# artificial immune system - 0
# active learning - 0
# micr - 0
# intelligent character recognition - 0
# optical braille recognition - 0
# email filtering - 0
# q-learning - 0
# proximal policy optimization - 0
# trust region policy optimization - 0
# challenge–response spam filtering - 0

# %%
for k in term_count.keys():
    if term_count[k]['#papers'] > 20:
        print(f"term: {k} - #papers: {term_count[k]['#papers']} - taxonomies: {term_count[k]['taxonomies']}")
# Out:
# term: general - #papers: 990 - taxonomies: ['papers_with_code']
# term: stochastic optimization - #papers: 57 - taxonomies: ['papers_with_code']
# term: computer vision - #papers: 974 - taxonomies: ['papers_with_code']
# term: one-stage object detection models - #papers: 22 - taxonomies: ['papers_with_code']
# term: object detection models - #papers: 61 - taxonomies: ['papers_with_code']
# term: graphs - #papers: 108 - taxonomies: ['papers_with_code']
# term: skip connection blocks - #papers: 46 - taxonomies: ['papers_with_code']
# term: audio - #papers: 57 - taxonomies: ['papers_with_code']
# term: generative adversarial networks - #papers: 43 - taxonomies: ['papers_with_code']
# term: graph models - #papers: 61 - taxonomies: ['papers_with_code']
# term: feature extractors - #papers: 26 - taxonomies: ['papers_with_code']
# term: attention mechanisms - #papers: 72 - taxonomies: ['papers_with_code']
# term: sequential - #papers: 73 - taxonomies: ['papers_with_code']
# term: activation functions - #papers: 62 - taxonomies: ['papers_with_code']
# term: natural language processing - #papers: 286 - taxonomies: ['papers_with_code', 'wikidata_ai', 'cso']
# term: transformers - #papers: 81 - taxonomies: ['papers_with_code']
# term: generative models - #papers: 64 - taxonomies: ['papers_with_code']
# term: reinforcement learning - #papers: 101 - taxonomies: ['papers_with_code', 'wikidata_ai', 'wikidata_ml']
# term: language models - #papers: 47 - taxonomies: ['papers_with_code']
# term: regularization - #papers: 53 - taxonomies: ['papers_with_code']
# term: normalization - #papers: 37 - taxonomies: ['papers_with_code']
# term: image model blocks - #papers: 90 - taxonomies: ['papers_with_code']
# term: convolutional neural networks - #papers: 116 - taxonomies: ['papers_with_code']
# term: graph embeddings - #papers: 36 - taxonomies: ['papers_with_code']
# term: image models - #papers: 33 - taxonomies: ['papers_with_code']
# term: vision transformers - #papers: 43 - taxonomies: ['papers_with_code']
# term: image data augmentation - #papers: 33 - taxonomies: ['papers_with_code']
# term: self-supervised learning - #papers: 51 - taxonomies: ['papers_with_code', 'wikidata_ai', 'wikidata_ml']
# term: autoencoding transformers - #papers: 28 - taxonomies: ['papers_with_code']
# term: optimization - #papers: 28 - taxonomies: ['papers_with_code']
# term: convolutions - #papers: 41 - taxonomies: ['papers_with_code']
# term: deep tabular learning - #papers: 26 - taxonomies: ['papers_with_code']
# term: loss functions - #papers: 37 - taxonomies: ['papers_with_code']
# term: semi-supervised learning methods - #papers: 23 - taxonomies: ['papers_with_code']
# term: semantic segmentation models - #papers: 31 - taxonomies: ['papers_with_code']
# term: vision and language pre-trained models - #papers: 28 - taxonomies: ['papers_with_code']
# term: attention modules - #papers: 41 - taxonomies: ['papers_with_code']
# term: recurrent neural networks - #papers: 32 - taxonomies: ['papers_with_code']
# term: policy gradient methods - #papers: 23 - taxonomies: ['papers_with_code']
# term: distributed methods - #papers: 39 - taxonomies: ['papers_with_code']

# %%
for k in term_count.keys():
    if len(term_count[k]['taxonomies']) > 1:
        print(f"term: {k} - #papers: {term_count[k]['#papers']} - taxonomies: {term_count[k]['taxonomies']}")
# Out:
# term: natural language processing - #papers: 286 - taxonomies: ['papers_with_code', 'wikidata_ai', 'cso']
# term: reinforcement learning - #papers: 101 - taxonomies: ['papers_with_code', 'wikidata_ai', 'wikidata_ml']
# term: heuristic search algorithms - #papers: 7 - taxonomies: ['papers_with_code', 'cso']
# term: self-supervised learning - #papers: 51 - taxonomies: ['papers_with_code', 'wikidata_ai', 'wikidata_ml']
# term: active learning - #papers: 6 - taxonomies: ['papers_with_code', 'wikidata_ai', 'wikidata_ml']
# term: knowledge distillation - #papers: 12 - taxonomies: ['papers_with_code', 'wikidata_ai', 'wikidata_ml']
# term: structured prediction - #papers: 5 - taxonomies: ['papers_with_code', 'wikidata_ai', 'wikidata_ml']
# term: prompt engineering - #papers: 3 - taxonomies: ['papers_with_code', 'wikidata_ai']
# term: speech recognition - #papers: 5 - taxonomies: ['papers_with_code', 'wikidata_ai']
# term: inference engines - #papers: 2 - taxonomies: ['papers_with_code', 'cso']
# term: machine learning - #papers: 13 - taxonomies: ['wikidata_ai', 'cso']
# term: expert system - #papers: 2 - taxonomies: ['wikidata_ai', 'cso']
# term: decision support system - #papers: 2 - taxonomies: ['wikidata_ai', 'cso']
# term: affective computing - #papers: 2 - taxonomies: ['wikidata_ai', 'cso']
# term: evolutionary computation - #papers: 2 - taxonomies: ['wikidata_ai', 'cso']
# term: knowledge engineering - #papers: 2 - taxonomies: ['wikidata_ai', 'cso']
# term: distributed artificial intelligence - #papers: 4 - taxonomies: ['wikidata_ai', 'cso']
# term: federated learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: explanation-based learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: pattern recognition - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: hierarchical temporal memory - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: chemometrics - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: unsupervised learning - #papers: 3 - taxonomies: ['wikidata_ai', 'wikidata_ml', 'cso']
# term: statistical classification - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: transfer learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: meta-learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: multi-task learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: nonlinear dimensionality reduction - #papers: 3 - taxonomies: ['wikidata_ai', 'wikidata_ml', 'cso']
# term: offline learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: one-shot learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: online machine learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: preference learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: robot learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: statistical relational learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: feature learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: quantum machine learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: adversarial machine learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: multiple kernel learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: multimodal learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: m-theory - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: rule-based machine learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: incremental learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: machine learning in bioinformatics - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: sequence-to-sequence learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: automated machine learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: image-to-image translation - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: interactive machine learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: end-to-end learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: machine learning in physics - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: zero-shot learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: gossip learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: declarative machine learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: byy harmony learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: few-shot learning - #papers: 3 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: pathways - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: semi-supervised and unsupervised learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: personalized machine learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: continual learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: imbalanced learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: natural language understanding - #papers: 2 - taxonomies: ['wikidata_ai', 'cso']
# term: natural language generation - #papers: 2 - taxonomies: ['wikidata_ai', 'cso']
# term: optical character recognition - #papers: 8 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: handwriting recognition - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: model-free reinforcement learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: deep reinforcement learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: multi-agent reinforcement learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: policy-gradient method - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: reinforcement learning from human feedback - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: quantitative structure-activity relationship - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: proteochemometrics - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: quantitative structure–property relationship - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: independent component analysis - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: archetypal analysis - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: boosting - #papers: 2 - taxonomies: ['wikidata_ai', 'cso']
# term: document classification - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: multiclass classification - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: binary classification - #papers: 3 - taxonomies: ['wikidata_ai', 'wikidata_ml', 'cso']
# term: deep transfer learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: isomap - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: sparse dictionary learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: artificial immune system - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: genetic algorithm - #papers: 2 - taxonomies: ['wikidata_ai', 'cso']
# term: micr - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: intelligent character recognition - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: optical braille recognition - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: email filtering - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: q-learning - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: proximal policy optimization - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: trust region policy optimization - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']
# term: challenge–response spam filtering - #papers: 2 - taxonomies: ['wikidata_ai', 'wikidata_ml']

# %%
with open('tax_results.json', 'w') as outfile:
    json.dump(term_count, outfile, indent=4)
